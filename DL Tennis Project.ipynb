# %%
import cv2
import mediapipe as mp
import numpy as np
import pandas as pd
from scipy.signal import savgol_filter
import os
from tqdm import tqdm
import glob 
import shutil
from sklearn.model_selection import train_test_split
from collections import defaultdict

# %% [markdown]
# ## MediaPipe, normalization and smoothing

# %%
class TennisSkeletonExtractor:

    # initialization the MediaPipe Pose model
    def __init__(self, min_detection_confidence=0.5, min_tracking_confidence=0.5):
        self.mp_pose = mp.solutions.pose
        self.pose = self.mp_pose.Pose(
            static_image_mode=False,       # optimized for video stream
            model_complexity=2,            # highest accuracy model
            smooth_landmarks=True,         # reduce jitter internally
            min_detection_confidence=min_detection_confidence,
            min_tracking_confidence=min_tracking_confidence
        )

    #  feature Extraction from a video file frame by frame with Sanity Check 
    def get_landmarks(self, video_path, jump_threshold=0.15):

        cap = cv2.VideoCapture(video_path)
        landmarks_data = []
        
        # variable to store the players position in the previous frame
        prev_hip_center = None 
        
        while cap.isOpened():
            success, image = cap.read()
            
            #stop if video ends or frame is empty
            if not success or image is None:
                break
            
            try:
                # convert BGR to RGB 
                image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            except cv2.error:
                continue

            # process the frame to find pose landmarks
            results = self.pose.process(image_rgb)
            
            frame_landmarks = []
            is_valid_frame = False
            
            if results.pose_landmarks:
                # extract landmarks into a flat list
                temp_landmarks = []
                for landmark in results.pose_landmarks.landmark:
                    temp_landmarks.extend([landmark.x, landmark.y, landmark.z, landmark.visibility])
                
                # calculate current hip center
                idx_l = 23 * 4 
                idx_r = 24 * 4  
                
                cx = (temp_landmarks[idx_l] + temp_landmarks[idx_r]) / 2
                cy = (temp_landmarks[idx_l+1] + temp_landmarks[idx_r+1]) / 2
                current_center = np.array([cx, cy])
                
                # compare distance to previous frame
                if prev_hip_center is not None:
                    dist = np.linalg.norm(current_center - prev_hip_center)
                    
                    # if movement is smaller than threshold, valid 
                    if dist < jump_threshold:
                        frame_landmarks = temp_landmarks
                        prev_hip_center = current_center
                        is_valid_frame = True
                    else:
                        # else, not
                        is_valid_frame = False 
                else:
                    # first frame is always valid
                    frame_landmarks = temp_landmarks
                    prev_hip_center = current_center
                    is_valid_frame = True
            
            # append landmarks if valid, otherwise append NaN
            if is_valid_frame:
                landmarks_data.append(frame_landmarks)
            else:
                landmarks_data.append([np.nan] * (33 * 4))
                
        cap.release()
        
        cols = []
        for i in range(33):
            cols.extend([f'x_{i}', f'y_{i}', f'z_{i}', f'v_{i}'])
            
        return pd.DataFrame(landmarks_data, columns=cols)

    # normalization
    def normalize_skeleton(self, df):

        # calculate Hip center
        hip_x = (df['x_23'] + df['x_24']) / 2
        hip_y = (df['y_23'] + df['y_24']) / 2
        
        # calculate torso size
        sh_x = (df['x_11'] + df['x_12']) / 2
        sh_y = (df['y_11'] + df['y_12']) / 2
        
        # distance
        torso_size = np.sqrt((sh_x - hip_x)**2 + (sh_y - hip_y)**2)
        torso_size = torso_size.replace(0, 1.0) # avoid division by zero

        # apply to all landmarks
        norm_df = df.copy()
        for i in range(33):
            norm_df[f'x_{i}'] = (df[f'x_{i}'] - hip_x) / torso_size
            norm_df[f'y_{i}'] = (df[f'y_{i}'] - hip_y) / torso_size
            
        return norm_df

    # smoothing jittery movements
    def smooth_data(self, df, window=5, poly=3):
        
        # fix NaNs from sanity check
        df_filled = df.interpolate(method='linear', limit_direction='both')
        
        # apply smoothing filter
        smoothed = df_filled.copy()
        for col in df_filled.columns:
            try:
                smoothed[col] = savgol_filter(df_filled[col], window, poly)
            except ValueError:
                # if video is too short for the filter window, skip smoothing
                pass
                
        return smoothed

# %% [markdown]
# ### Main Processing Loop

# %%
base_path = r'C:\Users\Noam\OneDrive\Desktop\DL_project\dataset\VIDEO_RGB'
output_base = r'C:\Users\Noam\OneDrive\Desktop\DL_project\dataset\PROCESSED_DATA'

if not os.path.exists(output_base):
    os.makedirs(output_base)
    print(f"Created output directory: {output_base}")

extractor = TennisSkeletonExtractor()


classes = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]
print(f"Found {len(classes)} classes: {classes}")

# iterate over each class folder
for class_name in classes:
    class_input_dir = os.path.join(base_path, class_name)
    class_output_dir = os.path.join(output_base, class_name)
    
    # create class output folder
    if not os.path.exists(class_output_dir):
        os.makedirs(class_output_dir)
        
    # list of video files
    videos = [f for f in os.listdir(class_input_dir) if f.endswith(('.avi', '.mp4'))]
    print(f"\nProcessing class: {class_name} ({len(videos)} videos)...")
    
    for video_file in tqdm(videos):
        video_path = os.path.join(class_input_dir, video_file)
        save_path = os.path.join(class_output_dir, video_file.replace('.avi', '.csv').replace('.mp4', '.csv'))
        
        if os.path.exists(save_path):
            continue
            
        try:
            # extract raw landmarks
            raw_df = extractor.get_landmarks(video_path)
            
            # skip empty videos or failed extractions
            if raw_df.empty:
                continue 

            # normalizetion
            norm_df = extractor.normalize_skeleton(raw_df)
            
            #  smoothing
            clean_df = extractor.smooth_data(norm_df)
            
            # save to CSV
            clean_df.to_csv(save_path, index=False)
            
        except Exception as e:
            print(f"Error processing {video_file}: {e}")

print("\n--- Full Dataset Processing Complete! ---")
# Out:
# Created output directory: C:\Users\Noam\OneDrive\Desktop\DL_project\dataset\PROCESSED_DATA
# Found 12 classes: ['backhand', 'backhand2hands', 'backhand_slice', 'backhand_volley', 'flat_service', 'forehand_flat', 'forehand_openstands', 'forehand_slice', 'forehand_volley', 'kick_service', 'slice_service', 'smash']
#
# Processing class: backhand (165 videos)...
# 100%|██████████| 165/165 [18:22<00:00,  6.68s/it]
# Processing class: backhand2hands (165 videos)...
# 100%|██████████| 165/165 [19:16<00:00,  7.01s/it]
# Processing class: backhand_slice (165 videos)...
# 100%|██████████| 165/165 [17:41<00:00,  6.43s/it]
# Processing class: backhand_volley (165 videos)...
# 100%|██████████| 165/165 [16:55<00:00,  6.15s/it]
# Processing class: flat_service (165 videos)...
# 100%|██████████| 165/165 [19:56<00:00,  7.25s/it]
# Processing class: forehand_flat (165 videos)...
# 100%|██████████| 165/165 [18:56<00:00,  6.89s/it]
# Processing class: forehand_openstands (165 videos)...
# 100%|██████████| 165/165 [16:39<00:00,  6.06s/it]
# Processing class: forehand_slice (165 videos)...
# 100%|██████████| 165/165 [17:08<00:00,  6.23s/it]
# Processing class: forehand_volley (165 videos)...
# 100%|██████████| 165/165 [15:43<00:00,  5.72s/it]
# Processing class: kick_service (165 videos)...
# 100%|██████████| 165/165 [19:58<00:00,  7.26s/it]
# Processing class: slice_service (165 videos)...
# 100%|██████████| 165/165 [18:41<00:00,  6.79s/it]
# Processing class: smash (165 videos)...
# 100%|██████████| 165/165 [17:08<00:00,  6.23s/it]
# --- Full Dataset Processing Complete! ---

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# ### Mirroring the data

# %%
ROOT_DIR = r'C:\Users\Noam\OneDrive\Desktop\DL_project\dataset\PROCESSED_DATA'

# MediaPipe (left <->right)
POSE_PAIRS = [
    # face
    (1, 4), (2, 5), (3, 6), (7, 8), (9, 10),
    # torso
    (11, 12), (13, 14), (15, 16),
    # hands
    (17, 18), (19, 20), (21, 22),
    # pelvis
    (23, 24), (25, 26), (27, 28),
    # legs
    (29, 30), (31, 32)
]

def create_mirror_csv(file_path):
    try:
        df = pd.read_csv(file_path)
        
        flipped_df = df.copy()

        for i in range(33):
            col_x = f'x_{i}'
            if col_x in df.columns:
                flipped_df[col_x] = 1.0 - df[col_x]

        for idx_a, idx_b in POSE_PAIRS:
            for params in ['x', 'y', 'z', 'v']:
                col_a = f'{params}_{idx_a}'
                col_b = f'{params}_{idx_b}'
                
                if col_a in df.columns and col_b in df.columns:
                    flipped_df[col_a] = df[col_b] 
                    flipped_df[col_b] = df[col_a] 

        # data.csv -> data_flipped.csv
        new_filename = file_path.replace('.csv', '_flipped.csv')
        flipped_df.to_csv(new_filename, index=False)
        print(f"Created: {os.path.basename(new_filename)}")

    except Exception as e:
        print(f"Error processing {file_path}: {e}")

for root, dirs, files in os.walk(ROOT_DIR):
    for file in files:
        if file.endswith(".csv") and "_flipped" not in file:
            full_path = os.path.join(root, file)
            create_mirror_csv(full_path)

print("Succeeded. Mirror augmentation complete.")
# Out:
# Created: p10_backhand_s1_flipped.csv
# Created: p10_backhand_s2_flipped.csv
# Created: p10_backhand_s3_flipped.csv
# Created: p11_backhand_s1_flipped.csv
# Created: p11_backhand_s2_flipped.csv
# Created: p11_backhand_s3_flipped.csv
# Created: p12_backhand_s1_flipped.csv
# Created: p12_backhand_s2_flipped.csv
# Created: p12_backhand_s3_flipped.csv
# Created: p13_backhand_s1_flipped.csv
# Created: p13_backhand_s2_flipped.csv
# Created: p13_backhand_s3_flipped.csv
# Created: p14_backhand_s1_flipped.csv
# Created: p14_backhand_s2_flipped.csv
# Created: p14_backhand_s3_flipped.csv
# Created: p15_backhand_s1_flipped.csv
# Created: p15_backhand_s2_flipped.csv
# Created: p15_backhand_s3_flipped.csv
# Created: p16_backhand_s1_flipped.csv
# Created: p16_backhand_s2_flipped.csv
# Created: p16_backhand_s3_flipped.csv
# Created: p17_backhand_s1_flipped.csv
# Created: p17_backhand_s2_flipped.csv
# Created: p17_backhand_s3_flipped.csv
# Created: p18_backhand_s1_flipped.csv
# Created: p18_backhand_s2_flipped.csv
# Created: p18_backhand_s3_flipped.csv
# Created: p19_backhand_s1_flipped.csv
# Created: p19_backhand_s2_flipped.csv
# Created: p19_backhand_s3_flipped.csv
# Created: p1_backhand_s1_flipped.csv
# Created: p1_backhand_s2_flipped.csv
# Created: p1_backhand_s3_flipped.csv
# Created: p20_backhand_s1_flipped.csv
# Created: p20_backhand_s2_flipped.csv
# Created: p20_backhand_s3_flipped.csv
# Created: p21_backhand_s1_flipped.csv
# Created: p21_backhand_s2_flipped.csv
# Created: p21_backhand_s3_flipped.csv
# Created: p22_backhand_s1_flipped.csv
# Created: p22_backhand_s2_flipped.csv
# Created: p22_backhand_s3_flipped.csv
# Created: p23_backhand_s1_flipped.csv
# Created: p23_backhand_s2_flipped.csv
# Created: p23_backhand_s3_flipped.csv
# Created: p24_backhand_s1_flipped.csv
# Created: p24_backhand_s2_flipped.csv
# Created: p24_backhand_s3_flipped.csv
# Created: p25_backhand_s1_flipped.csv
# Created: p25_backhand_s2_flipped.csv
# Created: p25_backhand_s3_flipped.csv
# Created: p26_backhand_s1_flipped.csv
# Created: p26_backhand_s2_flipped.csv
# Created: p26_backhand_s3_flipped.csv
# Created: p27_backhand_s1_flipped.csv
# Created: p27_backhand_s2_flipped.csv
# Created: p27_backhand_s3_flipped.csv
# Created: p28_backhand_s1_flipped.csv
# Created: p28_backhand_s2_flipped.csv
# Created: p28_backhand_s3_flipped.csv
# Created: p29_backhand_s1_flipped.csv
# Created: p29_backhand_s2_flipped.csv
# Created: p29_backhand_s3_flipped.csv
# Created: p2_backhand_s1_flipped.csv
# Created: p2_backhand_s2_flipped.csv
# Created: p2_backhand_s3_flipped.csv
# Created: p30_backhand_s1_flipped.csv
# Created: p30_backhand_s2_flipped.csv
# Created: p30_backhand_s3_flipped.csv
# Created: p31_backhand_s1_flipped.csv
# Created: p31_backhand_s2_flipped.csv
# Created: p31_backhand_s3_flipped.csv
# Created: p32_backhand_s1_flipped.csv
# Created: p32_backhand_s2_flipped.csv
# Created: p32_backhand_s3_flipped.csv
# Created: p33_backhand_s1_flipped.csv
# Created: p33_backhand_s2_flipped.csv
# Created: p33_backhand_s3_flipped.csv
# Created: p34_backhand_s1_flipped.csv
# Created: p34_backhand_s2_flipped.csv
# Created: p34_backhand_s3_flipped.csv
# Created: p35_backhand_s1_flipped.csv
# Created: p35_backhand_s2_flipped.csv
# Created: p35_backhand_s3_flipped.csv
# Created: p36_backhand_s1_flipped.csv
# Created: p36_backhand_s2_flipped.csv
# Created: p36_backhand_s3_flipped.csv
# Created: p37_backhand_s1_flipped.csv
# Created: p37_backhand_s2_flipped.csv
# Created: p37_backhand_s3_flipped.csv
# Created: p38_backhand_s1_flipped.csv
# Created: p38_backhand_s2_flipped.csv
# Created: p38_backhand_s3_flipped.csv
# Created: p39_backhand_s1_flipped.csv
# Created: p39_backhand_s2_flipped.csv
# Created: p39_backhand_s3_flipped.csv
# Created: p3_backhand_s1_flipped.csv
# Created: p3_backhand_s2_flipped.csv
# Created: p3_backhand_s3_flipped.csv
# Created: p40_backhand_s1_flipped.csv
# Created: p40_backhand_s2_flipped.csv
# Created: p40_backhand_s3_flipped.csv
# Created: p41_backhand_s1_flipped.csv
# Created: p41_backhand_s2_flipped.csv
# Created: p41_backhand_s3_flipped.csv
# Created: p42_backhand_s1_flipped.csv
# Created: p42_backhand_s2_flipped.csv
# Created: p42_backhand_s3_flipped.csv
# Created: p43_backhand_s1_flipped.csv
# Created: p43_backhand_s2_flipped.csv
# Created: p43_backhand_s3_flipped.csv
# Created: p44_backhand_s1_flipped.csv
# Created: p44_backhand_s2_flipped.csv
# Created: p44_backhand_s3_flipped.csv
# Created: p45_backhand_s1_flipped.csv
# Created: p45_backhand_s2_flipped.csv
# Created: p45_backhand_s3_flipped.csv
# Created: p46_backhand_s1_flipped.csv
# Created: p46_backhand_s2_flipped.csv
# Created: p46_backhand_s3_flipped.csv
# Created: p47_backhand_s1_flipped.csv
# Created: p47_backhand_s2_flipped.csv
# Created: p47_backhand_s3_flipped.csv
# Created: p48_backhand_s1_flipped.csv
# Created: p48_backhand_s2_flipped.csv
# Created: p48_backhand_s3_flipped.csv
# Created: p49_backhand_s1_flipped.csv
# Created: p49_backhand_s2_flipped.csv
# Created: p49_backhand_s3_flipped.csv
# Created: p4_backhand_s1_flipped.csv
# Created: p4_backhand_s2_flipped.csv
# Created: p4_backhand_s3_flipped.csv
# Created: p50_backhand_s1_flipped.csv
# Created: p50_backhand_s2_flipped.csv
# Created: p50_backhand_s3_flipped.csv
# Created: p51_backhand_s1_flipped.csv
# Created: p51_backhand_s2_flipped.csv
# Created: p51_backhand_s3_flipped.csv
# Created: p52_backhand_s1_flipped.csv
# Created: p52_backhand_s2_flipped.csv
# Created: p52_backhand_s3_flipped.csv
# Created: p53_backhand_s1_flipped.csv
# Created: p53_backhand_s2_flipped.csv
# Created: p53_backhand_s3_flipped.csv
# Created: p54_backhand_s1_flipped.csv
# Created: p54_backhand_s2_flipped.csv
# Created: p54_backhand_s3_flipped.csv
# Created: p55_backhand_s1_flipped.csv
# Created: p55_backhand_s2_flipped.csv
# Created: p55_backhand_s3_flipped.csv
# Created: p5_backhand_s1_flipped.csv
# Created: p5_backhand_s2_flipped.csv
# Created: p5_backhand_s3_flipped.csv
# Created: p6_backhand_s1_flipped.csv
# Created: p6_backhand_s2_flipped.csv
# Created: p6_backhand_s3_flipped.csv
# Created: p7_backhand_s1_flipped.csv
# Created: p7_backhand_s2_flipped.csv
# Created: p7_backhand_s3_flipped.csv
# Created: p8_backhand_s1_flipped.csv
# Created: p8_backhand_s2_flipped.csv
# Created: p8_backhand_s3_flipped.csv
# Created: p9_backhand_s1_flipped.csv
# Created: p9_backhand_s2_flipped.csv
# Created: p9_backhand_s3_flipped.csv
# Created: p10_backhand2h_s1_flipped.csv
# Created: p10_backhand2h_s2_flipped.csv
# Created: p10_backhand2h_s3_flipped.csv
# Created: p11_backhand2h_s1_flipped.csv
# Created: p11_backhand2h_s2_flipped.csv
# Created: p11_backhand2h_s3_flipped.csv
# Created: p12_backhand2h_s1_flipped.csv
# Created: p12_backhand2h_s2_flipped.csv
# Created: p12_backhand2h_s3_flipped.csv
# Created: p13_backhand2h_s1_flipped.csv
# Created: p13_backhand2h_s2_flipped.csv
# Created: p13_backhand2h_s3_flipped.csv
# Created: p14_backhand2h_s1_flipped.csv
# Created: p14_backhand2h_s2_flipped.csv
# Created: p14_backhand2h_s3_flipped.csv
# Created: p15_backhand2h_s1_flipped.csv
# Created: p15_backhand2h_s2_flipped.csv
# Created: p15_backhand2h_s3_flipped.csv
# Created: p16_backhand2h_s1_flipped.csv
# Created: p16_backhand2h_s2_flipped.csv
# Created: p16_backhand2h_s3_flipped.csv
# Created: p17_backhand2h_s1_flipped.csv
# Created: p17_backhand2h_s2_flipped.csv
# Created: p17_backhand2h_s3_flipped.csv
# Created: p18_backhand2h_s1_flipped.csv
# Created: p18_backhand2h_s2_flipped.csv
# Created: p18_backhand2h_s3_flipped.csv
# Created: p19_backhand2h_s1_flipped.csv
# Created: p19_backhand2h_s2_flipped.csv
# Created: p19_backhand2h_s3_flipped.csv
# Created: p1_backhand2h_s1_flipped.csv
# Created: p1_backhand2h_s2_flipped.csv
# Created: p1_backhand2h_s3_flipped.csv
# Created: p20_backhand2h_s1_flipped.csv
# Created: p20_backhand2h_s2_flipped.csv
# Created: p20_backhand2h_s3_flipped.csv
# Created: p21_backhand2h_s1_flipped.csv
# Created: p21_backhand2h_s2_flipped.csv
# Created: p21_backhand2h_s3_flipped.csv
# Created: p22_backhand2h_s1_flipped.csv
# Created: p22_backhand2h_s2_flipped.csv
# Created: p22_backhand2h_s3_flipped.csv
# Created: p23_backhand2h_s1_flipped.csv
# Created: p23_backhand2h_s2_flipped.csv
# Created: p23_backhand2h_s3_flipped.csv
# Created: p24_backhand2h_s1_flipped.csv
# Created: p24_backhand2h_s2_flipped.csv
# Created: p24_backhand2h_s3_flipped.csv
# Created: p25_backhand2h_s1_flipped.csv
# Created: p25_backhand2h_s2_flipped.csv
# Created: p25_backhand2h_s3_flipped.csv
# Created: p26_backhand2h_s1_flipped.csv
# Created: p26_backhand2h_s2_flipped.csv
# Created: p26_backhand2h_s3_flipped.csv
# Created: p27_backhand2h_s1_flipped.csv
# Created: p27_backhand2h_s2_flipped.csv
# Created: p27_backhand2h_s3_flipped.csv
# Created: p28_backhand2h_s1_flipped.csv
# Created: p28_backhand2h_s2_flipped.csv
# Created: p28_backhand2h_s3_flipped.csv
# Created: p29_backhand2h_s1_flipped.csv
# Created: p29_backhand2h_s2_flipped.csv
# Created: p29_backhand2h_s3_flipped.csv
# Created: p2_backhand2h_s1_flipped.csv
# Created: p2_backhand2h_s2_flipped.csv
# Created: p2_backhand2h_s3_flipped.csv
# Created: p30_backhand2h_s1_flipped.csv
# Created: p30_backhand2h_s2_flipped.csv
# Created: p30_backhand2h_s3_flipped.csv
# Created: p31_backhand2h_s1_flipped.csv
# Created: p31_backhand2h_s2_flipped.csv
# Created: p31_backhand2h_s3_flipped.csv
# Created: p32_backhand2h_s1_flipped.csv
# Created: p32_backhand2h_s2_flipped.csv
# Created: p32_backhand2h_s3_flipped.csv
# Created: p33_backhand2h_s1_flipped.csv
# Created: p33_backhand2h_s2_flipped.csv
# Created: p33_backhand2h_s3_flipped.csv
# Created: p34_backhand2h_s1_flipped.csv
# Created: p34_backhand2h_s2_flipped.csv
# Created: p34_backhand2h_s3_flipped.csv
# Created: p35_backhand2h_s1_flipped.csv
# Created: p35_backhand2h_s2_flipped.csv
# Created: p35_backhand2h_s3_flipped.csv
# Created: p36_backhand2h_s1_flipped.csv
# Created: p36_backhand2h_s2_flipped.csv
# Created: p36_backhand2h_s3_flipped.csv
# Created: p37_backhand2h_s1_flipped.csv
# Created: p37_backhand2h_s2_flipped.csv
# Created: p37_backhand2h_s3_flipped.csv
# Created: p38_backhand2h_s1_flipped.csv
# Created: p38_backhand2h_s2_flipped.csv
# Created: p38_backhand2h_s3_flipped.csv
# Created: p39_backhand2h_s1_flipped.csv
# Created: p39_backhand2h_s2_flipped.csv
# Created: p39_backhand2h_s3_flipped.csv
# Created: p3_backhand2h_s1_flipped.csv
# Created: p3_backhand2h_s2_flipped.csv
# Created: p3_backhand2h_s3_flipped.csv
# Created: p40_backhand2h_s1_flipped.csv
# Created: p40_backhand2h_s2_flipped.csv
# Created: p40_backhand2h_s3_flipped.csv
# Created: p41_backhand2h_s1_flipped.csv
# Created: p41_backhand2h_s2_flipped.csv
# Created: p41_backhand2h_s3_flipped.csv
# Created: p42_backhand2h_s1_flipped.csv
# Created: p42_backhand2h_s2_flipped.csv
# Created: p42_backhand2h_s3_flipped.csv
# Created: p43_backhand2h_s1_flipped.csv
# Created: p43_backhand2h_s2_flipped.csv
# Created: p43_backhand2h_s3_flipped.csv
# Created: p44_backhand2h_s1_flipped.csv
# Created: p44_backhand2h_s2_flipped.csv
# Created: p44_backhand2h_s3_flipped.csv
# Created: p45_backhand2h_s1_flipped.csv
# Created: p45_backhand2h_s2_flipped.csv
# Created: p45_backhand2h_s3_flipped.csv
# Created: p46_backhand2h_s1_flipped.csv
# Created: p46_backhand2h_s2_flipped.csv
# Created: p46_backhand2h_s3_flipped.csv
# Created: p47_backhand2h_s1_flipped.csv
# Created: p47_backhand2h_s2_flipped.csv
# Created: p47_backhand2h_s3_flipped.csv
# Created: p48_backhand2h_s1_flipped.csv
# Created: p48_backhand2h_s2_flipped.csv
# Created: p48_backhand2h_s3_flipped.csv
# Created: p49_backhand2h_s1_flipped.csv
# Created: p49_backhand2h_s2_flipped.csv
# Created: p49_backhand2h_s3_flipped.csv
# Created: p4_backhand2h_s1_flipped.csv
# Created: p4_backhand2h_s2_flipped.csv
# Created: p4_backhand2h_s3_flipped.csv
# Created: p50_backhand2h_s1_flipped.csv
# Created: p50_backhand2h_s2_flipped.csv
# Created: p50_backhand2h_s3_flipped.csv
# Created: p51_backhand2h_s1_flipped.csv
# Created: p51_backhand2h_s2_flipped.csv
# Created: p51_backhand2h_s3_flipped.csv
# Created: p52_backhand2h_s1_flipped.csv
# Created: p52_backhand2h_s2_flipped.csv
# Created: p52_backhand2h_s3_flipped.csv
# Created: p53_backhand2h_s1_flipped.csv
# Created: p53_backhand2h_s2_flipped.csv
# Created: p53_backhand2h_s3_flipped.csv
# Created: p54_backhand2h_s1_flipped.csv
# Created: p54_backhand2h_s2_flipped.csv
# Created: p54_backhand2h_s3_flipped.csv
# Created: p55_backhand2h_s1_flipped.csv
# Created: p55_backhand2h_s2_flipped.csv
# Created: p55_backhand2h_s3_flipped.csv
# Created: p5_backhand2h_s1_flipped.csv
# Created: p5_backhand2h_s2_flipped.csv
# Created: p5_backhand2h_s3_flipped.csv
# Created: p6_backhand2h_s1_flipped.csv
# Created: p6_backhand2h_s2_flipped.csv
# Created: p6_backhand2h_s3_flipped.csv
# Created: p7_backhand2h_s1_flipped.csv
# Created: p7_backhand2h_s2_flipped.csv
# Created: p7_backhand2h_s3_flipped.csv
# Created: p8_backhand2h_s1_flipped.csv
# Created: p8_backhand2h_s2_flipped.csv
# Created: p8_backhand2h_s3_flipped.csv
# Created: p9_backhand2h_s1_flipped.csv
# Created: p9_backhand2h_s2_flipped.csv
# Created: p9_backhand2h_s3_flipped.csv
# Created: p10_bslice_s1_flipped.csv
# Created: p10_bslice_s2_flipped.csv
# Created: p10_bslice_s3_flipped.csv
# Created: p11_bslice_s1_flipped.csv
# Created: p11_bslice_s2_flipped.csv
# Created: p11_bslice_s3_flipped.csv
# Created: p12_bslice_s1_flipped.csv
# Created: p12_bslice_s2_flipped.csv
# Created: p12_bslice_s3_flipped.csv
# Created: p13_bslice_s1_flipped.csv
# Created: p13_bslice_s2_flipped.csv
# Created: p13_bslice_s3_flipped.csv
# Created: p14_bslice_s1_flipped.csv
# Created: p14_bslice_s2_flipped.csv
# Created: p14_bslice_s3_flipped.csv
# Created: p15_bslice_s1_flipped.csv
# Created: p15_bslice_s2_flipped.csv
# Created: p15_bslice_s3_flipped.csv
# Created: p16_bslice_s1_flipped.csv
# Created: p16_bslice_s2_flipped.csv
# Created: p16_bslice_s3_flipped.csv
# Created: p17_bslice_s1_flipped.csv
# Created: p17_bslice_s2_flipped.csv
# Created: p17_bslice_s3_flipped.csv
# Created: p18_bslice_s1_flipped.csv
# Created: p18_bslice_s2_flipped.csv
# Created: p18_bslice_s3_flipped.csv
# Created: p19_bslice_s1_flipped.csv
# Created: p19_bslice_s2_flipped.csv
# Created: p19_bslice_s3_flipped.csv
# Created: p1_bslice_s1_flipped.csv
# Created: p1_bslice_s2_flipped.csv
# Created: p1_bslice_s3_flipped.csv
# Created: p20_bslice_s1_flipped.csv
# Created: p20_bslice_s2_flipped.csv
# Created: p20_bslice_s3_flipped.csv
# Created: p21_bslice_s1_flipped.csv
# Created: p21_bslice_s2_flipped.csv
# Created: p21_bslice_s3_flipped.csv
# Created: p22_bslice_s1_flipped.csv
# Created: p22_bslice_s2_flipped.csv
# Created: p22_bslice_s3_flipped.csv
# Created: p23_bslice_s1_flipped.csv
# Created: p23_bslice_s2_flipped.csv
# Created: p23_bslice_s3_flipped.csv
# Created: p24_bslice_s1_flipped.csv
# Created: p24_bslice_s2_flipped.csv
# Created: p24_bslice_s3_flipped.csv
# Created: p25_bslice_s1_flipped.csv
# Created: p25_bslice_s2_flipped.csv
# Created: p25_bslice_s3_flipped.csv
# Created: p26_bslice_s1_flipped.csv
# Created: p26_bslice_s2_flipped.csv
# Created: p26_bslice_s3_flipped.csv
# Created: p27_bslice_s1_flipped.csv
# Created: p27_bslice_s2_flipped.csv
# Created: p27_bslice_s3_flipped.csv
# Created: p28_bslice_s1_flipped.csv
# Created: p28_bslice_s2_flipped.csv
# Created: p28_bslice_s3_flipped.csv
# Created: p29_bslice_s1_flipped.csv
# Created: p29_bslice_s2_flipped.csv
# Created: p29_bslice_s3_flipped.csv
# Created: p2_bslice_s1_flipped.csv
# Created: p2_bslice_s2_flipped.csv
# Created: p2_bslice_s3_flipped.csv
# Created: p30_bslice_s1_flipped.csv
# Created: p30_bslice_s2_flipped.csv
# Created: p30_bslice_s3_flipped.csv
# Created: p31_bslice_s1_flipped.csv
# Created: p31_bslice_s2_flipped.csv
# Created: p31_bslice_s3_flipped.csv
# Created: p32_bslice_s1_flipped.csv
# Created: p32_bslice_s2_flipped.csv
# Created: p32_bslice_s3_flipped.csv
# Created: p33_bslice_s1_flipped.csv
# Created: p33_bslice_s2_flipped.csv
# Created: p33_bslice_s3_flipped.csv
# Created: p34_bslice_s1_flipped.csv
# Created: p34_bslice_s2_flipped.csv
# Created: p34_bslice_s3_flipped.csv
# Created: p35_bslice_s1_flipped.csv
# Created: p35_bslice_s2_flipped.csv
# Created: p35_bslice_s3_flipped.csv
# Created: p36_bslice_s1_flipped.csv
# Created: p36_bslice_s2_flipped.csv
# Created: p36_bslice_s3_flipped.csv
# Created: p37_bslice_s1_flipped.csv
# Created: p37_bslice_s2_flipped.csv
# Created: p37_bslice_s3_flipped.csv
# Created: p38_bslice_s1_flipped.csv
# Created: p38_bslice_s2_flipped.csv
# Created: p38_bslice_s3_flipped.csv
# Created: p39_bslice_s1_flipped.csv
# Created: p39_bslice_s2_flipped.csv
# Created: p39_bslice_s3_flipped.csv
# Created: p3_bslice_s1_flipped.csv
# Created: p3_bslice_s2_flipped.csv
# Created: p3_bslice_s3_flipped.csv
# Created: p40_bslice_s1_flipped.csv
# Created: p40_bslice_s2_flipped.csv
# Created: p40_bslice_s3_flipped.csv
# Created: p41_bslice_s1_flipped.csv
# Created: p41_bslice_s2_flipped.csv
# Created: p41_bslice_s3_flipped.csv
# Created: p42_bslice_s1_flipped.csv
# Created: p42_bslice_s2_flipped.csv
# Created: p42_bslice_s3_flipped.csv
# Created: p43_bslice_s1_flipped.csv
# Created: p43_bslice_s2_flipped.csv
# Created: p43_bslice_s3_flipped.csv
# Created: p44_bslice_s1_flipped.csv
# Created: p44_bslice_s2_flipped.csv
# Created: p44_bslice_s3_flipped.csv
# Created: p45_bslice_s1_flipped.csv
# Created: p45_bslice_s2_flipped.csv
# Created: p45_bslice_s3_flipped.csv
# Created: p46_bslice_s1_flipped.csv
# Created: p46_bslice_s2_flipped.csv
# Created: p46_bslice_s3_flipped.csv
# Created: p47_bslice_s1_flipped.csv
# Created: p47_bslice_s2_flipped.csv
# Created: p47_bslice_s3_flipped.csv
# Created: p48_bslice_s1_flipped.csv
# Created: p48_bslice_s2_flipped.csv
# Created: p48_bslice_s3_flipped.csv
# Created: p49_bslice_s1_flipped.csv
# Created: p49_bslice_s2_flipped.csv
# Created: p49_bslice_s3_flipped.csv
# Created: p4_bslice_s1_flipped.csv
# Created: p4_bslice_s2_flipped.csv
# Created: p4_bslice_s3_flipped.csv
# Created: p50_bslice_s1_flipped.csv
# Created: p50_bslice_s2_flipped.csv
# Created: p50_bslice_s3_flipped.csv
# Created: p51_bslice_s1_flipped.csv
# Created: p51_bslice_s2_flipped.csv
# Created: p51_bslice_s3_flipped.csv
# Created: p52_bslice_s1_flipped.csv
# Created: p52_bslice_s2_flipped.csv
# Created: p52_bslice_s3_flipped.csv
# Created: p53_bslice_s1_flipped.csv
# Created: p53_bslice_s2_flipped.csv
# Created: p53_bslice_s3_flipped.csv
# Created: p54_bslice_s1_flipped.csv
# Created: p54_bslice_s2_flipped.csv
# Created: p54_bslice_s3_flipped.csv
# Created: p55_bslice_s1_flipped.csv
# Created: p55_bslice_s2_flipped.csv
# Created: p55_bslice_s3_flipped.csv
# Created: p5_bslice_s1_flipped.csv
# Created: p5_bslice_s2_flipped.csv
# Created: p5_bslice_s3_flipped.csv
# Created: p6_bslice_s1_flipped.csv
# Created: p6_bslice_s2_flipped.csv
# Created: p6_bslice_s3_flipped.csv
# Created: p7_bslice_s1_flipped.csv
# Created: p7_bslice_s2_flipped.csv
# Created: p7_bslice_s3_flipped.csv
# Created: p8_bslice_s1_flipped.csv
# Created: p8_bslice_s2_flipped.csv
# Created: p8_bslice_s3_flipped.csv
# Created: p9_bslice_s1_flipped.csv
# Created: p9_bslice_s2_flipped.csv
# Created: p9_bslice_s3_flipped.csv
# Created: p10_bvolley_s1_flipped.csv
# Created: p10_bvolley_s2_flipped.csv
# Created: p10_bvolley_s3_flipped.csv
# Created: p11_bvolley_s1_flipped.csv
# Created: p11_bvolley_s2_flipped.csv
# Created: p11_bvolley_s3_flipped.csv
# Created: p12_bvolley_s1_flipped.csv
# Created: p12_bvolley_s2_flipped.csv
# Created: p12_bvolley_s3_flipped.csv
# Created: p13_bvolley_s1_flipped.csv
# Created: p13_bvolley_s2_flipped.csv
# Created: p13_bvolley_s3_flipped.csv
# Created: p14_bvolley_s1_flipped.csv
# Created: p14_bvolley_s2_flipped.csv
# Created: p14_bvolley_s3_flipped.csv
# Created: p15_bvolley_s1_flipped.csv
# Created: p15_bvolley_s2_flipped.csv
# Created: p15_bvolley_s3_flipped.csv
# Created: p16_bvolley_s1_flipped.csv
# Created: p16_bvolley_s2_flipped.csv
# Created: p16_bvolley_s3_flipped.csv
# Created: p17_bvolley_s1_flipped.csv
# Created: p17_bvolley_s2_flipped.csv
# Created: p17_bvolley_s3_flipped.csv
# Created: p18_bvolley_s1_flipped.csv
# Created: p18_bvolley_s2_flipped.csv
# Created: p18_bvolley_s3_flipped.csv
# Created: p19_bvolley_s1_flipped.csv
# Created: p19_bvolley_s2_flipped.csv
# Created: p19_bvolley_s3_flipped.csv
# Created: p1_bvolley_s1_flipped.csv
# Created: p1_bvolley_s2_flipped.csv
# Created: p1_bvolley_s3_flipped.csv
# Created: p20_bvolley_s1_flipped.csv
# Created: p20_bvolley_s2_flipped.csv
# Created: p20_bvolley_s3_flipped.csv
# Created: p21_bvolley_s1_flipped.csv
# Created: p21_bvolley_s2_flipped.csv
# Created: p21_bvolley_s3_flipped.csv
# Created: p22_bvolley_s1_flipped.csv
# Created: p22_bvolley_s2_flipped.csv
# Created: p22_bvolley_s3_flipped.csv
# Created: p23_bvolley_s1_flipped.csv
# Created: p23_bvolley_s2_flipped.csv
# Created: p23_bvolley_s3_flipped.csv
# Created: p24_bvolley_s1_flipped.csv
# Created: p24_bvolley_s2_flipped.csv
# Created: p24_bvolley_s3_flipped.csv
# Created: p25_bvolley_s1_flipped.csv
# Created: p25_bvolley_s2_flipped.csv
# Created: p25_bvolley_s3_flipped.csv
# Created: p26_bvolley_s1_flipped.csv
# Created: p26_bvolley_s2_flipped.csv
# Created: p26_bvolley_s3_flipped.csv
# Created: p27_bvolley_s1_flipped.csv
# Created: p27_bvolley_s2_flipped.csv
# Created: p27_bvolley_s3_flipped.csv
# Created: p28_bvolley_s1_flipped.csv
# Created: p28_bvolley_s2_flipped.csv
# Created: p28_bvolley_s3_flipped.csv
# Created: p29_bvolley_s1_flipped.csv
# Created: p29_bvolley_s2_flipped.csv
# Created: p29_bvolley_s3_flipped.csv
# Created: p2_bvolley_s1_flipped.csv
# Created: p2_bvolley_s2_flipped.csv
# Created: p2_bvolley_s3_flipped.csv
# Created: p30_bvolley_s1_flipped.csv
# Created: p30_bvolley_s2_flipped.csv
# Created: p30_bvolley_s3_flipped.csv
# Created: p31_bvolley_s1_flipped.csv
# Created: p31_bvolley_s2_flipped.csv
# Created: p31_bvolley_s3_flipped.csv
# Created: p32_bvolley_s1_flipped.csv
# Created: p32_bvolley_s2_flipped.csv
# Created: p32_bvolley_s3_flipped.csv
# Created: p33_bvolley_s1_flipped.csv
# Created: p33_bvolley_s2_flipped.csv
# Created: p33_bvolley_s3_flipped.csv
# Created: p34_bvolley_s1_flipped.csv
# Created: p34_bvolley_s2_flipped.csv
# Created: p34_bvolley_s3_flipped.csv
# Created: p35_bvolley_s1_flipped.csv
# Created: p35_bvolley_s2_flipped.csv
# Created: p35_bvolley_s3_flipped.csv
# Created: p36_bvolley_s1_flipped.csv
# Created: p36_bvolley_s2_flipped.csv
# Created: p36_bvolley_s3_flipped.csv
# Created: p37_bvolley_s1_flipped.csv
# Created: p37_bvolley_s2_flipped.csv
# Created: p37_bvolley_s3_flipped.csv
# Created: p38_bvolley_s1_flipped.csv
# Created: p38_bvolley_s2_flipped.csv
# Created: p38_bvolley_s3_flipped.csv
# Created: p39_bvolley_s1_flipped.csv
# Created: p39_bvolley_s2_flipped.csv
# Created: p39_bvolley_s3_flipped.csv
# Created: p3_bvolley_s1_flipped.csv
# Created: p3_bvolley_s2_flipped.csv
# Created: p3_bvolley_s3_flipped.csv
# Created: p40_bvolley_s1_flipped.csv
# Created: p40_bvolley_s2_flipped.csv
# Created: p40_bvolley_s3_flipped.csv
# Created: p41_bvolley_s1_flipped.csv
# Created: p41_bvolley_s2_flipped.csv
# Created: p41_bvolley_s3_flipped.csv
# Created: p42_bvolley_s1_flipped.csv
# Created: p42_bvolley_s2_flipped.csv
# Created: p42_bvolley_s3_flipped.csv
# Created: p43_bvolley_s1_flipped.csv
# Created: p43_bvolley_s2_flipped.csv
# Created: p43_bvolley_s3_flipped.csv
# Created: p44_bvolley_s1_flipped.csv
# Created: p44_bvolley_s2_flipped.csv
# Created: p44_bvolley_s3_flipped.csv
# Created: p45_bvolley_s1_flipped.csv
# Created: p45_bvolley_s2_flipped.csv
# Created: p45_bvolley_s3_flipped.csv
# Created: p46_bvolley_s1_flipped.csv
# Created: p46_bvolley_s2_flipped.csv
# Created: p46_bvolley_s3_flipped.csv
# Created: p47_bvolley_s1_flipped.csv
# Created: p47_bvolley_s2_flipped.csv
# Created: p47_bvolley_s3_flipped.csv
# Created: p48_bvolley_s1_flipped.csv
# Created: p48_bvolley_s2_flipped.csv
# Created: p48_bvolley_s3_flipped.csv
# Created: p49_bvolley_s1_flipped.csv
# Created: p49_bvolley_s2_flipped.csv
# Created: p49_bvolley_s3_flipped.csv
# Created: p4_bvolley_s1_flipped.csv
# Created: p4_bvolley_s2_flipped.csv
# Created: p4_bvolley_s3_flipped.csv
# Created: p50_bvolley_s1_flipped.csv
# Created: p50_bvolley_s2_flipped.csv
# Created: p50_bvolley_s3_flipped.csv
# Created: p51_bvolley_s1_flipped.csv
# Created: p51_bvolley_s2_flipped.csv
# Created: p51_bvolley_s3_flipped.csv
# Created: p52_bvolley_s1_flipped.csv
# Created: p52_bvolley_s2_flipped.csv
# Created: p52_bvolley_s3_flipped.csv
# Created: p53_bvolley_s1_flipped.csv
# Created: p53_bvolley_s2_flipped.csv
# Created: p53_bvolley_s3_flipped.csv
# Created: p54_bvolley_s1_flipped.csv
# Created: p54_bvolley_s2_flipped.csv
# Created: p54_bvolley_s3_flipped.csv
# Created: p55_bvolley_s1_flipped.csv
# Created: p55_bvolley_s2_flipped.csv
# Created: p55_bvolley_s3_flipped.csv
# Created: p5_bvolley_s1_flipped.csv
# Created: p5_bvolley_s2_flipped.csv
# Created: p5_bvolley_s3_flipped.csv
# Created: p6_bvolley_s1_flipped.csv
# Created: p6_bvolley_s2_flipped.csv
# Created: p6_bvolley_s3_flipped.csv
# Created: p7_bvolley_s1_flipped.csv
# Created: p7_bvolley_s2_flipped.csv
# Created: p7_bvolley_s3_flipped.csv
# Created: p8_bvolley_s1_flipped.csv
# Created: p8_bvolley_s2_flipped.csv
# Created: p8_bvolley_s3_flipped.csv
# Created: p9_bvolley_s1_flipped.csv
# Created: p9_bvolley_s2_flipped.csv
# Created: p9_bvolley_s3_flipped.csv
# Created: p10_serflat_s1_flipped.csv
# Created: p10_serflat_s2_flipped.csv
# Created: p10_serflat_s3_flipped.csv
# Created: p11_serflat_s1_flipped.csv
# Created: p11_serflat_s2_flipped.csv
# Created: p11_serflat_s3_flipped.csv
# Created: p12_serflat_s1_flipped.csv
# Created: p12_serflat_s2_flipped.csv
# Created: p12_serflat_s3_flipped.csv
# Created: p13_serflat_s1_flipped.csv
# Created: p13_serflat_s2_flipped.csv
# Created: p13_serflat_s3_flipped.csv
# Created: p14_serflat_s1_flipped.csv
# Created: p14_serflat_s2_flipped.csv
# Created: p14_serflat_s3_flipped.csv
# Created: p15_serflat_s1_flipped.csv
# Created: p15_serflat_s2_flipped.csv
# Created: p15_serflat_s3_flipped.csv
# Created: p16_serflat_s1_flipped.csv
# Created: p16_serflat_s2_flipped.csv
# Created: p16_serflat_s3_flipped.csv
# Created: p17_serflat_s1_flipped.csv
# Created: p17_serflat_s2_flipped.csv
# Created: p17_serflat_s3_flipped.csv
# Created: p18_serflat_s1_flipped.csv
# Created: p18_serflat_s2_flipped.csv
# Created: p18_serflat_s3_flipped.csv
# Created: p19_serflat_s1_flipped.csv
# Created: p19_serflat_s2_flipped.csv
# Created: p19_serflat_s3_flipped.csv
# Created: p1_serflat_s1_flipped.csv
# Created: p1_serflat_s2_flipped.csv
# Created: p1_serflat_s3_flipped.csv
# Created: p20_serflat_s1_flipped.csv
# Created: p20_serflat_s2_flipped.csv
# Created: p20_serflat_s3_flipped.csv
# Created: p21_serflat_s1_flipped.csv
# Created: p21_serflat_s2_flipped.csv
# Created: p21_serflat_s3_flipped.csv
# Created: p22_serflat_s1_flipped.csv
# Created: p22_serflat_s2_flipped.csv
# Created: p22_serflat_s3_flipped.csv
# Created: p23_serflat_s1_flipped.csv
# Created: p23_serflat_s2_flipped.csv
# Created: p23_serflat_s3_flipped.csv
# Created: p24_serflat_s1_flipped.csv
# Created: p24_serflat_s2_flipped.csv
# Created: p24_serflat_s3_flipped.csv
# Created: p25_serflat_s1_flipped.csv
# Created: p25_serflat_s2_flipped.csv
# Created: p25_serflat_s3_flipped.csv
# Created: p26_serflat_s1_flipped.csv
# Created: p26_serflat_s2_flipped.csv
# Created: p26_serflat_s3_flipped.csv
# Created: p27_serflat_s1_flipped.csv
# Created: p27_serflat_s2_flipped.csv
# Created: p27_serflat_s3_flipped.csv
# Created: p28_serflat_s1_flipped.csv
# Created: p28_serflat_s2_flipped.csv
# Created: p28_serflat_s3_flipped.csv
# Created: p29_serflat_s1_flipped.csv
# Created: p29_serflat_s2_flipped.csv
# Created: p29_serflat_s3_flipped.csv
# Created: p2_serflat_s1_flipped.csv
# Created: p2_serflat_s2_flipped.csv
# Created: p2_serflat_s3_flipped.csv
# Created: p30_serflat_s1_flipped.csv
# Created: p30_serflat_s2_flipped.csv
# Created: p30_serflat_s3_flipped.csv
# Created: p31_serflat_s1_flipped.csv
# Created: p31_serflat_s2_flipped.csv
# Created: p31_serflat_s3_flipped.csv
# Created: p32_serflat_s1_flipped.csv
# Created: p32_serflat_s2_flipped.csv
# Created: p32_serflat_s3_flipped.csv
# Created: p33_serflat_s1_flipped.csv
# Created: p33_serflat_s2_flipped.csv
# Created: p33_serflat_s3_flipped.csv
# Created: p34_serflat_s1_flipped.csv
# Created: p34_serflat_s2_flipped.csv
# Created: p34_serflat_s3_flipped.csv
# Created: p35_serflat_s1_flipped.csv
# Created: p35_serflat_s2_flipped.csv
# Created: p35_serflat_s3_flipped.csv
# Created: p36_serflat_s1_flipped.csv
# Created: p36_serflat_s2_flipped.csv
# Created: p36_serflat_s3_flipped.csv
# Created: p37_serflat_s1_flipped.csv
# Created: p37_serflat_s2_flipped.csv
# Created: p37_serflat_s3_flipped.csv
# Created: p38_serflat_s1_flipped.csv
# Created: p38_serflat_s2_flipped.csv
# Created: p38_serflat_s3_flipped.csv
# Created: p39_serflat_s1_flipped.csv
# Created: p39_serflat_s2_flipped.csv
# Created: p39_serflat_s3_flipped.csv
# Created: p3_serflat_s1_flipped.csv
# Created: p3_serflat_s2_flipped.csv
# Created: p3_serflat_s3_flipped.csv
# Created: p40_serflat_s1_flipped.csv
# Created: p40_serflat_s2_flipped.csv
# Created: p40_serflat_s3_flipped.csv
# Created: p41_serflat_s1_flipped.csv
# Created: p41_serflat_s2_flipped.csv
# Created: p41_serflat_s3_flipped.csv
# Created: p42_serflat_s1_flipped.csv
# Created: p42_serflat_s2_flipped.csv
# Created: p42_serflat_s3_flipped.csv
# Created: p43_serflat_s1_flipped.csv
# Created: p43_serflat_s2_flipped.csv
# Created: p43_serflat_s3_flipped.csv
# Created: p44_serflat_s1_flipped.csv
# Created: p44_serflat_s2_flipped.csv
# Created: p44_serflat_s3_flipped.csv
# Created: p45_serflat_s1_flipped.csv
# Created: p45_serflat_s2_flipped.csv
# Created: p45_serflat_s3_flipped.csv
# Created: p46_serflat_s1_flipped.csv
# Created: p46_serflat_s2_flipped.csv
# Created: p46_serflat_s3_flipped.csv
# Created: p47_serflat_s1_flipped.csv
# Created: p47_serflat_s2_flipped.csv
# Created: p47_serflat_s3_flipped.csv
# Created: p48_serflat_s1_flipped.csv
# Created: p48_serflat_s2_flipped.csv
# Created: p48_serflat_s3_flipped.csv
# Created: p49_serflat_s1_flipped.csv
# Created: p49_serflat_s2_flipped.csv
# Created: p49_serflat_s3_flipped.csv
# Created: p4_serflat_s1_flipped.csv
# Created: p4_serflat_s2_flipped.csv
# Created: p4_serflat_s3_flipped.csv
# Created: p50_serflat_s1_flipped.csv
# Created: p50_serflat_s2_flipped.csv
# Created: p50_serflat_s3_flipped.csv
# Created: p51_serflat_s1_flipped.csv
# Created: p51_serflat_s2_flipped.csv
# Created: p51_serflat_s3_flipped.csv
# Created: p52_serflat_s1_flipped.csv
# Created: p52_serflat_s2_flipped.csv
# Created: p52_serflat_s3_flipped.csv
# Created: p53_serflat_s1_flipped.csv
# Created: p53_serflat_s2_flipped.csv
# Created: p53_serflat_s3_flipped.csv
# Created: p54_serflat_s1_flipped.csv
# Created: p54_serflat_s2_flipped.csv
# Created: p54_serflat_s3_flipped.csv
# Created: p55_serflat_s1_flipped.csv
# Created: p55_serflat_s2_flipped.csv
# Created: p55_serflat_s3_flipped.csv
# Created: p5_serflat_s1_flipped.csv
# Created: p5_serflat_s2_flipped.csv
# Created: p5_serflat_s3_flipped.csv
# Created: p6_serflat_s1_flipped.csv
# Created: p6_serflat_s2_flipped.csv
# Created: p6_serflat_s3_flipped.csv
# Created: p7_serflat_s1_flipped.csv
# Created: p7_serflat_s2_flipped.csv
# Created: p7_serflat_s3_flipped.csv
# Created: p8_serflat_s1_flipped.csv
# Created: p8_serflat_s2_flipped.csv
# Created: p8_serflat_s3_flipped.csv
# Created: p9_serflat_s1_flipped.csv
# Created: p9_serflat_s2_flipped.csv
# Created: p9_serflat_s3_flipped.csv
# Created: p10_foreflat_s1_flipped.csv
# Created: p10_foreflat_s2_flipped.csv
# Created: p10_foreflat_s3_flipped.csv
# Created: p11_foreflat_s1_flipped.csv
# Created: p11_foreflat_s2_flipped.csv
# Created: p11_foreflat_s3_flipped.csv
# Created: p12_foreflat_s1_flipped.csv
# Created: p12_foreflat_s2_flipped.csv
# Created: p12_foreflat_s3_flipped.csv
# Created: p13_foreflat_s1_flipped.csv
# Created: p13_foreflat_s2_flipped.csv
# Created: p13_foreflat_s3_flipped.csv
# Created: p14_foreflat_s1_flipped.csv
# Created: p14_foreflat_s2_flipped.csv
# Created: p14_foreflat_s3_flipped.csv
# Created: p15_foreflat_s1_flipped.csv
# Created: p15_foreflat_s2_flipped.csv
# Created: p15_foreflat_s3_flipped.csv
# Created: p16_foreflat_s1_flipped.csv
# Created: p16_foreflat_s2_flipped.csv
# Created: p16_foreflat_s3_flipped.csv
# Created: p17_foreflat_s1_flipped.csv
# Created: p17_foreflat_s2_flipped.csv
# Created: p17_foreflat_s3_flipped.csv
# Created: p18_foreflat_s1_flipped.csv
# Created: p18_foreflat_s2_flipped.csv
# Created: p18_foreflat_s3_flipped.csv
# Created: p19_foreflat_s1_flipped.csv
# Created: p19_foreflat_s2_flipped.csv
# Created: p19_foreflat_s3_flipped.csv
# Created: p1_foreflat_s1_flipped.csv
# Created: p1_foreflat_s2_flipped.csv
# Created: p1_foreflat_s3_flipped.csv
# Created: p20_foreflat_s1_flipped.csv
# Created: p20_foreflat_s2_flipped.csv
# Created: p20_foreflat_s3_flipped.csv
# Created: p21_foreflat_s1_flipped.csv
# Created: p21_foreflat_s2_flipped.csv
# Created: p21_foreflat_s3_flipped.csv
# Created: p22_foreflat_s1_flipped.csv
# Created: p22_foreflat_s2_flipped.csv
# Created: p22_foreflat_s3_flipped.csv
# Created: p23_foreflat_s1_flipped.csv
# Created: p23_foreflat_s2_flipped.csv
# Created: p23_foreflat_s3_flipped.csv
# Created: p24_foreflat_s1_flipped.csv
# Created: p24_foreflat_s2_flipped.csv
# Created: p24_foreflat_s3_flipped.csv
# Created: p25_foreflat_s1_flipped.csv
# Created: p25_foreflat_s2_flipped.csv
# Created: p25_foreflat_s3_flipped.csv
# Created: p26_foreflat_s1_flipped.csv
# Created: p26_foreflat_s2_flipped.csv
# Created: p26_foreflat_s3_flipped.csv
# Created: p27_foreflat_s1_flipped.csv
# Created: p27_foreflat_s2_flipped.csv
# Created: p27_foreflat_s3_flipped.csv
# Created: p28_foreflat_s1_flipped.csv
# Created: p28_foreflat_s2_flipped.csv
# Created: p28_foreflat_s3_flipped.csv
# Created: p29_foreflat_s1_flipped.csv
# Created: p29_foreflat_s2_flipped.csv
# Created: p29_foreflat_s3_flipped.csv
# Created: p2_foreflat_s1_flipped.csv
# Created: p2_foreflat_s2_flipped.csv
# Created: p2_foreflat_s3_flipped.csv
# Created: p30_foreflat_s1_flipped.csv
# Created: p30_foreflat_s2_flipped.csv
# Created: p30_foreflat_s3_flipped.csv
# Created: p31_foreflat_s1_flipped.csv
# Created: p31_foreflat_s2_flipped.csv
# Created: p31_foreflat_s3_flipped.csv
# Created: p32_foreflat_s1_flipped.csv
# Created: p32_foreflat_s2_flipped.csv
# Created: p32_foreflat_s3_flipped.csv
# Created: p33_foreflat_s1_flipped.csv
# Created: p33_foreflat_s2_flipped.csv
# Created: p33_foreflat_s3_flipped.csv
# Created: p34_foreflat_s1_flipped.csv
# Created: p34_foreflat_s2_flipped.csv
# Created: p34_foreflat_s3_flipped.csv
# Created: p35_foreflat_s1_flipped.csv
# Created: p35_foreflat_s2_flipped.csv
# Created: p35_foreflat_s3_flipped.csv
# Created: p36_foreflat_s1_flipped.csv
# Created: p36_foreflat_s2_flipped.csv
# Created: p36_foreflat_s3_flipped.csv
# Created: p37_foreflat_s1_flipped.csv
# Created: p37_foreflat_s2_flipped.csv
# Created: p37_foreflat_s3_flipped.csv
# Created: p38_foreflat_s1_flipped.csv
# Created: p38_foreflat_s2_flipped.csv
# Created: p38_foreflat_s3_flipped.csv
# Created: p39_foreflat_s1_flipped.csv
# Created: p39_foreflat_s2_flipped.csv
# Created: p39_foreflat_s3_flipped.csv
# Created: p3_foreflat_s1_flipped.csv
# Created: p3_foreflat_s2_flipped.csv
# Created: p3_foreflat_s3_flipped.csv
# Created: p40_foreflat_s1_flipped.csv
# Created: p40_foreflat_s2_flipped.csv
# Created: p40_foreflat_s3_flipped.csv
# Created: p41_foreflat_s1_flipped.csv
# Created: p41_foreflat_s2_flipped.csv
# Created: p41_foreflat_s3_flipped.csv
# Created: p42_foreflat_s1_flipped.csv
# Created: p42_foreflat_s2_flipped.csv
# Created: p42_foreflat_s3_flipped.csv
# Created: p43_foreflat_s1_flipped.csv
# Created: p43_foreflat_s2_flipped.csv
# Created: p43_foreflat_s3_flipped.csv
# Created: p44_foreflat_s1_flipped.csv
# Created: p44_foreflat_s2_flipped.csv
# Created: p44_foreflat_s3_flipped.csv
# Created: p45_foreflat_s1_flipped.csv
# Created: p45_foreflat_s2_flipped.csv
# Created: p45_foreflat_s3_flipped.csv
# Created: p46_foreflat_s1_flipped.csv
# Created: p46_foreflat_s2_flipped.csv
# Created: p46_foreflat_s3_flipped.csv
# Created: p47_foreflat_s1_flipped.csv
# Created: p47_foreflat_s2_flipped.csv
# Created: p47_foreflat_s3_flipped.csv
# Created: p48_foreflat_s1_flipped.csv
# Created: p48_foreflat_s2_flipped.csv
# Created: p48_foreflat_s3_flipped.csv
# Created: p49_foreflat_s1_flipped.csv
# Created: p49_foreflat_s2_flipped.csv
# Created: p49_foreflat_s3_flipped.csv
# Created: p4_foreflat_s1_flipped.csv
# Created: p4_foreflat_s2_flipped.csv
# Created: p4_foreflat_s3_flipped.csv
# Created: p50_foreflat_s1_flipped.csv
# Created: p50_foreflat_s2_flipped.csv
# Created: p50_foreflat_s3_flipped.csv
# Created: p51_foreflat_s1_flipped.csv
# Created: p51_foreflat_s2_flipped.csv
# Created: p51_foreflat_s3_flipped.csv
# Created: p52_foreflat_s1_flipped.csv
# Created: p52_foreflat_s2_flipped.csv
# Created: p52_foreflat_s3_flipped.csv
# Created: p53_foreflat_s1_flipped.csv
# Created: p53_foreflat_s2_flipped.csv
# Created: p53_foreflat_s3_flipped.csv
# Created: p54_foreflat_s1_flipped.csv
# Created: p54_foreflat_s2_flipped.csv
# Created: p54_foreflat_s3_flipped.csv
# Created: p55_foreflat_s1_flipped.csv
# Created: p55_foreflat_s2_flipped.csv
# Created: p55_foreflat_s3_flipped.csv
# Created: p5_foreflat_s1_flipped.csv
# Created: p5_foreflat_s2_flipped.csv
# Created: p5_foreflat_s3_flipped.csv
# Created: p6_foreflat_s1_flipped.csv
# Created: p6_foreflat_s2_flipped.csv
# Created: p6_foreflat_s3_flipped.csv
# Created: p7_foreflat_s1_flipped.csv
# Created: p7_foreflat_s2_flipped.csv
# Created: p7_foreflat_s3_flipped.csv
# Created: p8_foreflat_s1_flipped.csv
# Created: p8_foreflat_s2_flipped.csv
# Created: p8_foreflat_s3_flipped.csv
# Created: p9_foreflat_s1_flipped.csv
# Created: p9_foreflat_s2_flipped.csv
# Created: p9_foreflat_s3_flipped.csv
# Created: p10_foreopen_s1_flipped.csv
# Created: p10_foreopen_s2_flipped.csv
# Created: p10_foreopen_s3_flipped.csv
# Created: p11_foreopen_s1_flipped.csv
# Created: p11_foreopen_s2_flipped.csv
# Created: p11_foreopen_s3_flipped.csv
# Created: p12_foreopen_s1_flipped.csv
# Created: p12_foreopen_s2_flipped.csv
# Created: p12_foreopen_s3_flipped.csv
# Created: p13_foreopen_s1_flipped.csv
# Created: p13_foreopen_s2_flipped.csv
# Created: p13_foreopen_s3_flipped.csv
# Created: p14_foreopen_s1_flipped.csv
# Created: p14_foreopen_s2_flipped.csv
# Created: p14_foreopen_s3_flipped.csv
# Created: p15_foreopen_s1_flipped.csv
# Created: p15_foreopen_s2_flipped.csv
# Created: p15_foreopen_s3_flipped.csv
# Created: p16_foreopen_s1_flipped.csv
# Created: p16_foreopen_s2_flipped.csv
# Created: p16_foreopen_s3_flipped.csv
# Created: p17_foreopen_s1_flipped.csv
# Created: p17_foreopen_s2_flipped.csv
# Created: p17_foreopen_s3_flipped.csv
# Created: p18_foreopen_s1_flipped.csv
# Created: p18_foreopen_s2_flipped.csv
# Created: p18_foreopen_s3_flipped.csv
# Created: p19_foreopen_s1_flipped.csv
# Created: p19_foreopen_s2_flipped.csv
# Created: p19_foreopen_s3_flipped.csv
# Created: p1_foreopen_s1_flipped.csv
# Created: p1_foreopen_s2_flipped.csv
# Created: p1_foreopen_s3_flipped.csv
# Created: p20_foreopen_s1_flipped.csv
# Created: p20_foreopen_s2_flipped.csv
# Created: p20_foreopen_s3_flipped.csv
# Created: p21_foreopen_s1_flipped.csv
# Created: p21_foreopen_s2_flipped.csv
# Created: p21_foreopen_s3_flipped.csv
# Created: p22_foreopen_s1_flipped.csv
# Created: p22_foreopen_s2_flipped.csv
# Created: p22_foreopen_s3_flipped.csv
# Created: p23_foreopen_s1_flipped.csv
# Created: p23_foreopen_s2_flipped.csv
# Created: p23_foreopen_s3_flipped.csv
# Created: p24_foreopen_s1_flipped.csv
# Created: p24_foreopen_s2_flipped.csv
# Created: p24_foreopen_s3_flipped.csv
# Created: p25_foreopen_s1_flipped.csv
# Created: p25_foreopen_s2_flipped.csv
# Created: p25_foreopen_s3_flipped.csv
# Created: p26_foreopen_s1_flipped.csv
# Created: p26_foreopen_s2_flipped.csv
# Created: p26_foreopen_s3_flipped.csv
# Created: p27_foreopen_s1_flipped.csv
# Created: p27_foreopen_s2_flipped.csv
# Created: p27_foreopen_s3_flipped.csv
# Created: p28_foreopen_s1_flipped.csv
# Created: p28_foreopen_s2_flipped.csv
# Created: p28_foreopen_s3_flipped.csv
# Created: p29_foreopen_s1_flipped.csv
# Created: p29_foreopen_s2_flipped.csv
# Created: p29_foreopen_s3_flipped.csv
# Created: p2_foreopen_s1_flipped.csv
# Created: p2_foreopen_s2_flipped.csv
# Created: p2_foreopen_s3_flipped.csv
# Created: p30_foreopen_s1_flipped.csv
# Created: p30_foreopen_s2_flipped.csv
# Created: p30_foreopen_s3_flipped.csv
# Created: p31_foreopen_s1_flipped.csv
# Created: p31_foreopen_s2_flipped.csv
# Created: p31_foreopen_s3_flipped.csv
# Created: p32_foreopen_s1_flipped.csv
# Created: p32_foreopen_s2_flipped.csv
# Created: p32_foreopen_s3_flipped.csv
# Created: p33_foreopen_s1_flipped.csv
# Created: p33_foreopen_s2_flipped.csv
# Created: p33_foreopen_s3_flipped.csv
# Created: p34_foreopen_s1_flipped.csv
# Created: p34_foreopen_s2_flipped.csv
# Created: p34_foreopen_s3_flipped.csv
# Created: p35_foreopen_s1_flipped.csv
# Created: p35_foreopen_s2_flipped.csv
# Created: p35_foreopen_s3_flipped.csv
# Created: p36_foreopen_s1_flipped.csv
# Created: p36_foreopen_s2_flipped.csv
# Created: p36_foreopen_s3_flipped.csv
# Created: p37_foreopen_s1_flipped.csv
# Created: p37_foreopen_s2_flipped.csv
# Created: p37_foreopen_s3_flipped.csv
# Created: p38_foreopen_s1_flipped.csv
# Created: p38_foreopen_s2_flipped.csv
# Created: p38_foreopen_s3_flipped.csv
# Created: p39_foreopen_s1_flipped.csv
# Created: p39_foreopen_s2_flipped.csv
# Created: p39_foreopen_s3_flipped.csv
# Created: p3_foreopen_s1_flipped.csv
# Created: p3_foreopen_s2_flipped.csv
# Created: p3_foreopen_s3_flipped.csv
# Created: p40_foreopen_s1_flipped.csv
# Created: p40_foreopen_s2_flipped.csv
# Created: p40_foreopen_s3_flipped.csv
# Created: p41_foreopen_s1_flipped.csv
# Created: p41_foreopen_s2_flipped.csv
# Created: p41_foreopen_s3_flipped.csv
# Created: p42_foreopen_s1_flipped.csv
# Created: p42_foreopen_s2_flipped.csv
# Created: p42_foreopen_s3_flipped.csv
# Created: p43_foreopen_s1_flipped.csv
# Created: p43_foreopen_s2_flipped.csv
# Created: p43_foreopen_s3_flipped.csv
# Created: p44_foreopen_s1_flipped.csv
# Created: p44_foreopen_s2_flipped.csv
# Created: p44_foreopen_s3_flipped.csv
# Created: p45_foreopen_s1_flipped.csv
# Created: p45_foreopen_s2_flipped.csv
# Created: p45_foreopen_s3_flipped.csv
# Created: p46_foreopen_s1_flipped.csv
# Created: p46_foreopen_s2_flipped.csv
# Created: p46_foreopen_s3_flipped.csv
# Created: p47_foreopen_s1_flipped.csv
# Created: p47_foreopen_s2_flipped.csv
# Created: p47_foreopen_s3_flipped.csv
# Created: p48_foreopen_s1_flipped.csv
# Created: p48_foreopen_s2_flipped.csv
# Created: p48_foreopen_s3_flipped.csv
# Created: p49_foreopen_s1_flipped.csv
# Created: p49_foreopen_s2_flipped.csv
# Created: p49_foreopen_s3_flipped.csv
# Created: p4_foreopen_s1_flipped.csv
# Created: p4_foreopen_s2_flipped.csv
# Created: p4_foreopen_s3_flipped.csv
# Created: p50_foreopen_s1_flipped.csv
# Created: p50_foreopen_s2_flipped.csv
# Created: p50_foreopen_s3_flipped.csv
# Created: p51_foreopen_s1_flipped.csv
# Created: p51_foreopen_s2_flipped.csv
# Created: p51_foreopen_s3_flipped.csv
# Created: p52_foreopen_s1_flipped.csv
# Created: p52_foreopen_s2_flipped.csv
# Created: p52_foreopen_s3_flipped.csv
# Created: p53_foreopen_s1_flipped.csv
# Created: p53_foreopen_s2_flipped.csv
# Created: p53_foreopen_s3_flipped.csv
# Created: p54_foreopen_s1_flipped.csv
# Created: p54_foreopen_s2_flipped.csv
# Created: p54_foreopen_s3_flipped.csv
# Created: p55_foreopen_s1_flipped.csv
# Created: p55_foreopen_s2_flipped.csv
# Created: p55_foreopen_s3_flipped.csv
# Created: p5_foreopen_s1_flipped.csv
# Created: p5_foreopen_s2_flipped.csv
# Created: p5_foreopen_s3_flipped.csv
# Created: p6_foreopen_s1_flipped.csv
# Created: p6_foreopen_s2_flipped.csv
# Created: p6_foreopen_s3_flipped.csv
# Created: p7_foreopen_s1_flipped.csv
# Created: p7_foreopen_s2_flipped.csv
# Created: p7_foreopen_s3_flipped.csv
# Created: p8_foreopen_s1_flipped.csv
# Created: p8_foreopen_s2_flipped.csv
# Created: p8_foreopen_s3_flipped.csv
# Created: p9_foreopen_s1_flipped.csv
# Created: p9_foreopen_s2_flipped.csv
# Created: p9_foreopen_s3_flipped.csv
# Created: p10_fslice_s1_flipped.csv
# Created: p10_fslice_s2_flipped.csv
# Created: p10_fslice_s3_flipped.csv
# Created: p11_fslice_s1_flipped.csv
# Created: p11_fslice_s2_flipped.csv
# Created: p11_fslice_s3_flipped.csv
# Created: p12_fslice_s1_flipped.csv
# Created: p12_fslice_s2_flipped.csv
# Created: p12_fslice_s3_flipped.csv
# Created: p13_fslice_s1_flipped.csv
# Created: p13_fslice_s2_flipped.csv
# Created: p13_fslice_s3_flipped.csv
# Created: p14_fslice_s1_flipped.csv
# Created: p14_fslice_s2_flipped.csv
# Created: p14_fslice_s3_flipped.csv
# Created: p15_fslice_s1_flipped.csv
# Created: p15_fslice_s2_flipped.csv
# Created: p15_fslice_s3_flipped.csv
# Created: p16_fslice_s1_flipped.csv
# Created: p16_fslice_s2_flipped.csv
# Created: p16_fslice_s3_flipped.csv
# Created: p17_fslice_s1_flipped.csv
# Created: p17_fslice_s2_flipped.csv
# Created: p17_fslice_s3_flipped.csv
# Created: p18_fslice_s1_flipped.csv
# Created: p18_fslice_s2_flipped.csv
# Created: p18_fslice_s3_flipped.csv
# Created: p19_fslice_s1_flipped.csv
# Created: p19_fslice_s2_flipped.csv
# Created: p19_fslice_s3_flipped.csv
# Created: p1_fslice_s1_flipped.csv
# Created: p1_fslice_s2_flipped.csv
# Created: p1_fslice_s3_flipped.csv
# Created: p20_fslice_s1_flipped.csv
# Created: p20_fslice_s2_flipped.csv
# Created: p20_fslice_s3_flipped.csv
# Created: p21_fslice_s1_flipped.csv
# Created: p21_fslice_s2_flipped.csv
# Created: p21_fslice_s3_flipped.csv
# Created: p22_fslice_s1_flipped.csv
# Created: p22_fslice_s2_flipped.csv
# Created: p22_fslice_s3_flipped.csv
# Created: p23_fslice_s1_flipped.csv
# Created: p23_fslice_s2_flipped.csv
# Created: p23_fslice_s3_flipped.csv
# Created: p24_fslice_s1_flipped.csv
# Created: p24_fslice_s2_flipped.csv
# Created: p24_fslice_s3_flipped.csv
# Created: p25_fslice_s1_flipped.csv
# Created: p25_fslice_s2_flipped.csv
# Created: p25_fslice_s3_flipped.csv
# Created: p26_fslice_s1_flipped.csv
# Created: p26_fslice_s2_flipped.csv
# Created: p26_fslice_s3_flipped.csv
# Created: p27_fslice_s1_flipped.csv
# Created: p27_fslice_s2_flipped.csv
# Created: p27_fslice_s3_flipped.csv
# Created: p28_fslice_s1_flipped.csv
# Created: p28_fslice_s2_flipped.csv
# Created: p28_fslice_s3_flipped.csv
# Created: p29_fslice_s1_flipped.csv
# Created: p29_fslice_s2_flipped.csv
# Created: p29_fslice_s3_flipped.csv
# Created: p2_fslice_s1_flipped.csv
# Created: p2_fslice_s2_flipped.csv
# Created: p2_fslice_s3_flipped.csv
# Created: p30_fslice_s1_flipped.csv
# Created: p30_fslice_s2_flipped.csv
# Created: p30_fslice_s3_flipped.csv
# Created: p31_fslice_s1_flipped.csv
# Created: p31_fslice_s2_flipped.csv
# Created: p31_fslice_s3_flipped.csv
# Created: p32_fslice_s1_flipped.csv
# Created: p32_fslice_s2_flipped.csv
# Created: p32_fslice_s3_flipped.csv
# Created: p33_fslice_s1_flipped.csv
# Created: p33_fslice_s2_flipped.csv
# Created: p33_fslice_s3_flipped.csv
# Created: p34_fslice_s1_flipped.csv
# Created: p34_fslice_s2_flipped.csv
# Created: p34_fslice_s3_flipped.csv
# Created: p35_fslice_s1_flipped.csv
# Created: p35_fslice_s2_flipped.csv
# Created: p35_fslice_s3_flipped.csv
# Created: p36_fslice_s1_flipped.csv
# Created: p36_fslice_s2_flipped.csv
# Created: p36_fslice_s3_flipped.csv
# Created: p37_fslice_s1_flipped.csv
# Created: p37_fslice_s2_flipped.csv
# Created: p37_fslice_s3_flipped.csv
# Created: p38_fslice_s1_flipped.csv
# Created: p38_fslice_s2_flipped.csv
# Created: p38_fslice_s3_flipped.csv
# Created: p39_fslice_s1_flipped.csv
# Created: p39_fslice_s2_flipped.csv
# Created: p39_fslice_s3_flipped.csv
# Created: p3_fslice_s1_flipped.csv
# Created: p3_fslice_s2_flipped.csv
# Created: p3_fslice_s3_flipped.csv
# Created: p40_fslice_s1_flipped.csv
# Created: p40_fslice_s2_flipped.csv
# Created: p40_fslice_s3_flipped.csv
# Created: p41_fslice_s1_flipped.csv
# Created: p41_fslice_s2_flipped.csv
# Created: p41_fslice_s3_flipped.csv
# Created: p42_fslice_s1_flipped.csv
# Created: p42_fslice_s2_flipped.csv
# Created: p42_fslice_s3_flipped.csv
# Created: p43_fslice_s1_flipped.csv
# Created: p43_fslice_s2_flipped.csv
# Created: p43_fslice_s3_flipped.csv
# Created: p44_fslice_s1_flipped.csv
# Created: p44_fslice_s2_flipped.csv
# Created: p44_fslice_s3_flipped.csv
# Created: p45_fslice_s1_flipped.csv
# Created: p45_fslice_s2_flipped.csv
# Created: p45_fslice_s3_flipped.csv
# Created: p46_fslice_s1_flipped.csv
# Created: p46_fslice_s2_flipped.csv
# Created: p46_fslice_s3_flipped.csv
# Created: p47_fslice_s1_flipped.csv
# Created: p47_fslice_s2_flipped.csv
# Created: p47_fslice_s3_flipped.csv
# Created: p48_fslice_s1_flipped.csv
# Created: p48_fslice_s2_flipped.csv
# Created: p48_fslice_s3_flipped.csv
# Created: p49_fslice_s1_flipped.csv
# Created: p49_fslice_s2_flipped.csv
# Created: p49_fslice_s3_flipped.csv
# Created: p4_fslice_s1_flipped.csv
# Created: p4_fslice_s2_flipped.csv
# Created: p4_fslice_s3_flipped.csv
# Created: p50_fslice_s1_flipped.csv
# Created: p50_fslice_s2_flipped.csv
# Created: p50_fslice_s3_flipped.csv
# Created: p51_fslice_s1_flipped.csv
# Created: p51_fslice_s2_flipped.csv
# Created: p51_fslice_s3_flipped.csv
# Created: p52_fslice_s1_flipped.csv
# Created: p52_fslice_s2_flipped.csv
# Created: p52_fslice_s3_flipped.csv
# Created: p53_fslice_s1_flipped.csv
# Created: p53_fslice_s2_flipped.csv
# Created: p53_fslice_s3_flipped.csv
# Created: p54_fslice_s1_flipped.csv
# Created: p54_fslice_s2_flipped.csv
# Created: p54_fslice_s3_flipped.csv
# Created: p55_fslice_s1_flipped.csv
# Created: p55_fslice_s2_flipped.csv
# Created: p55_fslice_s3_flipped.csv
# Created: p5_fslice_s1_flipped.csv
# Created: p5_fslice_s2_flipped.csv
# Created: p5_fslice_s3_flipped.csv
# Created: p6_fslice_s1_flipped.csv
# Created: p6_fslice_s2_flipped.csv
# Created: p6_fslice_s3_flipped.csv
# Created: p7_fslice_s1_flipped.csv
# Created: p7_fslice_s2_flipped.csv
# Created: p7_fslice_s3_flipped.csv
# Created: p8_fslice_s1_flipped.csv
# Created: p8_fslice_s2_flipped.csv
# Created: p8_fslice_s3_flipped.csv
# Created: p9_fslice_s1_flipped.csv
# Created: p9_fslice_s2_flipped.csv
# Created: p9_fslice_s3_flipped.csv
# Created: p10_fvolley_s1_flipped.csv
# ...
# Created: p24_serkick_s1_flipped.csv
# Created: p24_serkick_s2_flipped.csv
# Created: p24_serkick_s3_flipped.csv
# Created: p25_serkick_s1_flipped.csv
# Created: p25_serkick_s2_flipped.csv
# Created: p25_serkick_s3_flipped.csv
# Created: p26_serkick_s1_flipped.csv
# Created: p26_serkick_s2_flipped.csv
# Created: p26_serkick_s3_flipped.csv
# Created: p27_serkick_s1_flipped.csv
# Created: p27_serkick_s2_flipped.csv
# Created: p27_serkick_s3_flipped.csv
# Created: p28_serkick_s1_flipped.csv
# Created: p28_serkick_s2_flipped.csv
# Created: p28_serkick_s3_flipped.csv
# Created: p29_serkick_s1_flipped.csv
# Created: p29_serkick_s2_flipped.csv
# Created: p29_serkick_s3_flipped.csv
# Created: p2_serkick_s1_flipped.csv
# Created: p2_serkick_s2_flipped.csv
# Created: p2_serkick_s3_flipped.csv
# Created: p30_serkick_s1_flipped.csv
# Created: p30_serkick_s2_flipped.csv
# Created: p30_serkick_s3_flipped.csv
# Created: p31_serkick_s1_flipped.csv
# Created: p31_serkick_s2_flipped.csv
# Created: p31_serkick_s3_flipped.csv
# Created: p32_serkick_s1_flipped.csv
# Created: p32_serkick_s2_flipped.csv
# Created: p32_serkick_s3_flipped.csv
# Created: p33_serkick_s1_flipped.csv
# Created: p33_serkick_s2_flipped.csv
# Created: p33_serkick_s3_flipped.csv
# Created: p34_serkick_s1_flipped.csv
# Created: p34_serkick_s2_flipped.csv
# Created: p34_serkick_s3_flipped.csv
# Created: p35_serkick_s1_flipped.csv
# Created: p35_serkick_s2_flipped.csv
# Created: p35_serkick_s3_flipped.csv
# Created: p36_serkick_s1_flipped.csv
# Created: p36_serkick_s2_flipped.csv
# Created: p36_serkick_s3_flipped.csv
# Created: p37_serkick_s1_flipped.csv
# Created: p37_serkick_s2_flipped.csv
# Created: p37_serkick_s3_flipped.csv
# Created: p38_serkick_s1_flipped.csv
# Created: p38_serkick_s2_flipped.csv
# Created: p38_serkick_s3_flipped.csv
# Created: p39_serkick_s1_flipped.csv
# Created: p39_serkick_s2_flipped.csv
# Created: p39_serkick_s3_flipped.csv
# Created: p3_serkick_s1_flipped.csv
# Created: p3_serkick_s2_flipped.csv
# Created: p3_serkick_s3_flipped.csv
# Created: p40_serkick_s1_flipped.csv
# Created: p40_serkick_s2_flipped.csv
# Created: p40_serkick_s3_flipped.csv
# Created: p41_serkick_s1_flipped.csv
# Created: p41_serkick_s2_flipped.csv
# Created: p41_serkick_s3_flipped.csv
# Created: p42_serkick_s1_flipped.csv
# Created: p42_serkick_s2_flipped.csv
# Created: p42_serkick_s3_flipped.csv
# Created: p43_serkick_s1_flipped.csv
# Created: p43_serkick_s2_flipped.csv
# Created: p43_serkick_s3_flipped.csv
# Created: p44_serkick_s1_flipped.csv
# Created: p44_serkick_s2_flipped.csv
# Created: p44_serkick_s3_flipped.csv
# Created: p45_serkick_s1_flipped.csv
# Created: p45_serkick_s2_flipped.csv
# Created: p45_serkick_s3_flipped.csv
# Created: p46_serkick_s1_flipped.csv
# Created: p46_serkick_s2_flipped.csv
# Created: p46_serkick_s3_flipped.csv
# Created: p47_serkick_s1_flipped.csv
# Created: p47_serkick_s2_flipped.csv
# Created: p47_serkick_s3_flipped.csv
# Created: p48_serkick_s1_flipped.csv
# Created: p48_serkick_s2_flipped.csv
# Created: p48_serkick_s3_flipped.csv
# Created: p49_serkick_s1_flipped.csv
# Created: p49_serkick_s2_flipped.csv
# Created: p49_serkick_s3_flipped.csv
# Created: p4_serkick_s1_flipped.csv
# Created: p4_serkick_s2_flipped.csv
# Created: p4_serkick_s3_flipped.csv
# Created: p50_serkick_s1_flipped.csv
# Created: p50_serkick_s2_flipped.csv
# Created: p50_serkick_s3_flipped.csv
# Created: p51_serkick_s1_flipped.csv
# Created: p51_serkick_s2_flipped.csv
# Created: p51_serkick_s3_flipped.csv
# Created: p52_serkick_s1_flipped.csv
# Created: p52_serkick_s2_flipped.csv
# Created: p52_serkick_s3_flipped.csv
# Created: p53_serkick_s1_flipped.csv
# Created: p53_serkick_s2_flipped.csv
# Created: p53_serkick_s3_flipped.csv
# Created: p54_serkick_s1_flipped.csv
# Created: p54_serkick_s2_flipped.csv
# Created: p54_serkick_s3_flipped.csv
# Created: p55_serkick_s1_flipped.csv
# Created: p55_serkick_s2_flipped.csv
# Created: p55_serkick_s3_flipped.csv
# Created: p5_serkick_s1_flipped.csv
# Created: p5_serkick_s2_flipped.csv
# Created: p5_serkick_s3_flipped.csv
# Created: p6_serkick_s1_flipped.csv
# Created: p6_serkick_s2_flipped.csv
# Created: p6_serkick_s3_flipped.csv
# Created: p7_serkick_s1_flipped.csv
# Created: p7_serkick_s2_flipped.csv
# Created: p7_serkick_s3_flipped.csv
# Created: p8_serkick_s1_flipped.csv
# Created: p8_serkick_s2_flipped.csv
# Created: p8_serkick_s3_flipped.csv
# Created: p9_serkick_s1_flipped.csv
# Created: p9_serkick_s2_flipped.csv
# Created: p9_serkick_s3_flipped.csv
# Created: p10_serslice_s1_flipped.csv
# Created: p10_serslice_s2_flipped.csv
# Created: p10_serslice_s3_flipped.csv
# Created: p11_serslice_s1_flipped.csv
# Created: p11_serslice_s2_flipped.csv
# Created: p11_serslice_s3_flipped.csv
# Created: p12_serslice_s1_flipped.csv
# Created: p12_serslice_s2_flipped.csv
# Created: p12_serslice_s3_flipped.csv
# Created: p13_serslice_s1_flipped.csv
# Created: p13_serslice_s2_flipped.csv
# Created: p13_serslice_s3_flipped.csv
# Created: p14_serslice_s1_flipped.csv
# Created: p14_serslice_s2_flipped.csv
# Created: p14_serslice_s3_flipped.csv
# Created: p15_serslice_s1_flipped.csv
# Created: p15_serslice_s2_flipped.csv
# Created: p15_serslice_s3_flipped.csv
# Created: p16_serslice_s1_flipped.csv
# Created: p16_serslice_s2_flipped.csv
# Created: p16_serslice_s3_flipped.csv
# Created: p17_serslice_s1_flipped.csv
# Created: p17_serslice_s2_flipped.csv
# Created: p17_serslice_s3_flipped.csv
# Created: p18_serslice_s1_flipped.csv
# Created: p18_serslice_s2_flipped.csv
# Created: p18_serslice_s3_flipped.csv
# Created: p19_serslice_s1_flipped.csv
# Created: p19_serslice_s2_flipped.csv
# Created: p19_serslice_s3_flipped.csv
# Created: p1_serslice_s1_flipped.csv
# Created: p1_serslice_s2_flipped.csv
# Created: p1_serslice_s3_flipped.csv
# Created: p20_serslice_s1_flipped.csv
# Created: p20_serslice_s2_flipped.csv
# Created: p20_serslice_s3_flipped.csv
# Created: p21_serslice_s1_flipped.csv
# Created: p21_serslice_s2_flipped.csv
# Created: p21_serslice_s3_flipped.csv
# Created: p22_serslice_s1_flipped.csv
# Created: p22_serslice_s2_flipped.csv
# Created: p22_serslice_s3_flipped.csv
# Created: p23_serslice_s1_flipped.csv
# Created: p23_serslice_s2_flipped.csv
# Created: p23_serslice_s3_flipped.csv
# Created: p24_serslice_s1_flipped.csv
# Created: p24_serslice_s2_flipped.csv
# Created: p24_serslice_s3_flipped.csv
# Created: p25_serslice_s1_flipped.csv
# Created: p25_serslice_s2_flipped.csv
# Created: p25_serslice_s3_flipped.csv
# Created: p26_serslice_s1_flipped.csv
# Created: p26_serslice_s2_flipped.csv
# Created: p26_serslice_s3_flipped.csv
# Created: p27_serslice_s1_flipped.csv
# Created: p27_serslice_s2_flipped.csv
# Created: p27_serslice_s3_flipped.csv
# Created: p28_serslice_s1_flipped.csv
# Created: p28_serslice_s2_flipped.csv
# Created: p28_serslice_s3_flipped.csv
# Created: p29_serslice_s1_flipped.csv
# Created: p29_serslice_s2_flipped.csv
# Created: p29_serslice_s3_flipped.csv
# Created: p2_serslice_s1_flipped.csv
# Created: p2_serslice_s2_flipped.csv
# Created: p2_serslice_s3_flipped.csv
# Created: p30_serslice_s1_flipped.csv
# Created: p30_serslice_s2_flipped.csv
# Created: p30_serslice_s3_flipped.csv
# Created: p31_serslice_s1_flipped.csv
# Created: p31_serslice_s2_flipped.csv
# Created: p31_serslice_s3_flipped.csv
# Created: p32_serslice_s1_flipped.csv
# Created: p32_serslice_s2_flipped.csv
# Created: p32_serslice_s3_flipped.csv
# Created: p33_serslice_s1_flipped.csv
# Created: p33_serslice_s2_flipped.csv
# Created: p33_serslice_s3_flipped.csv
# Created: p34_serslice_s1_flipped.csv
# Created: p34_serslice_s2_flipped.csv
# Created: p34_serslice_s3_flipped.csv
# Created: p35_serslice_s1_flipped.csv
# Created: p35_serslice_s2_flipped.csv
# Created: p35_serslice_s3_flipped.csv
# Created: p36_serslice_s1_flipped.csv
# Created: p36_serslice_s2_flipped.csv
# Created: p36_serslice_s3_flipped.csv
# Created: p37_serslice_s1_flipped.csv
# Created: p37_serslice_s2_flipped.csv
# Created: p37_serslice_s3_flipped.csv
# Created: p38_serslice_s1_flipped.csv
# Created: p38_serslice_s2_flipped.csv
# Created: p38_serslice_s3_flipped.csv
# Created: p39_serslice_s1_flipped.csv
# Created: p39_serslice_s2_flipped.csv
# Created: p39_serslice_s3_flipped.csv
# Created: p3_serslice_s1_flipped.csv
# Created: p3_serslice_s2_flipped.csv
# Created: p3_serslice_s3_flipped.csv
# Created: p40_serslice_s1_flipped.csv
# Created: p40_serslice_s2_flipped.csv
# Created: p40_serslice_s3_flipped.csv
# Created: p41_serslice_s1_flipped.csv
# Created: p41_serslice_s2_flipped.csv
# Created: p41_serslice_s3_flipped.csv
# Created: p42_serslice_s1_flipped.csv
# Created: p42_serslice_s2_flipped.csv
# Created: p42_serslice_s3_flipped.csv
# Created: p43_serslice_s1_flipped.csv
# Created: p43_serslice_s2_flipped.csv
# Created: p43_serslice_s3_flipped.csv
# Created: p44_serslice_s1_flipped.csv
# Created: p44_serslice_s2_flipped.csv
# Created: p44_serslice_s3_flipped.csv
# Created: p45_serslice_s1_flipped.csv
# Created: p45_serslice_s2_flipped.csv
# Created: p45_serslice_s3_flipped.csv
# Created: p46_serslice_s1_flipped.csv
# Created: p46_serslice_s2_flipped.csv
# Created: p46_serslice_s3_flipped.csv
# Created: p47_serslice_s1_flipped.csv
# Created: p47_serslice_s2_flipped.csv
# Created: p47_serslice_s3_flipped.csv
# Created: p48_serslice_s1_flipped.csv
# Created: p48_serslice_s2_flipped.csv
# Created: p48_serslice_s3_flipped.csv
# Created: p49_serslice_s1_flipped.csv
# Created: p49_serslice_s2_flipped.csv
# Created: p49_serslice_s3_flipped.csv
# Created: p4_serslice_s1_flipped.csv
# Created: p4_serslice_s2_flipped.csv
# Created: p4_serslice_s3_flipped.csv
# Created: p50_serslice_s1_flipped.csv
# Created: p50_serslice_s2_flipped.csv
# Created: p50_serslice_s3_flipped.csv
# Created: p51_serslice_s1_flipped.csv
# Created: p51_serslice_s2_flipped.csv
# Created: p51_serslice_s3_flipped.csv
# Created: p52_serslice_s1_flipped.csv
# Created: p52_serslice_s2_flipped.csv
# Created: p52_serslice_s3_flipped.csv
# Created: p53_serslice_s1_flipped.csv
# Created: p53_serslice_s2_flipped.csv
# Created: p53_serslice_s3_flipped.csv
# Created: p54_serslice_s1_flipped.csv
# Created: p54_serslice_s2_flipped.csv
# Created: p54_serslice_s3_flipped.csv
# Created: p55_serslice_s1_flipped.csv
# Created: p55_serslice_s2_flipped.csv
# Created: p55_serslice_s3_flipped.csv
# Created: p5_serslice_s1_flipped.csv
# Created: p5_serslice_s2_flipped.csv
# Created: p5_serslice_s3_flipped.csv
# Created: p6_serslice_s1_flipped.csv
# Created: p6_serslice_s2_flipped.csv
# Created: p6_serslice_s3_flipped.csv
# Created: p7_serslice_s1_flipped.csv
# Created: p7_serslice_s2_flipped.csv
# Created: p7_serslice_s3_flipped.csv
# Created: p8_serslice_s1_flipped.csv
# Created: p8_serslice_s2_flipped.csv
# Created: p8_serslice_s3_flipped.csv
# Created: p9_serslice_s1_flipped.csv
# Created: p9_serslice_s2_flipped.csv
# Created: p9_serslice_s3_flipped.csv
# Created: p10_smash_s1_flipped.csv
# Created: p10_smash_s2_flipped.csv
# Created: p10_smash_s3_flipped.csv
# Created: p11_smash_s1_flipped.csv
# Created: p11_smash_s2_flipped.csv
# Created: p11_smash_s3_flipped.csv
# Created: p12_smash_s1_flipped.csv
# Created: p12_smash_s2_flipped.csv
# Created: p12_smash_s3_flipped.csv
# Created: p13_smash_s1_flipped.csv
# Created: p13_smash_s2_flipped.csv
# Created: p13_smash_s3_flipped.csv
# Created: p14_smash_s1_flipped.csv
# Created: p14_smash_s2_flipped.csv
# Created: p14_smash_s3_flipped.csv
# Created: p15_smash_s1_flipped.csv
# Created: p15_smash_s2_flipped.csv
# Created: p15_smash_s3_flipped.csv
# Created: p16_smash_s1_flipped.csv
# Created: p16_smash_s2_flipped.csv
# Created: p16_smash_s3_flipped.csv
# Created: p17_smash_s1_flipped.csv
# Created: p17_smash_s2_flipped.csv
# Created: p17_smash_s3_flipped.csv
# Created: p18_smash_s1_flipped.csv
# Created: p18_smash_s2_flipped.csv
# Created: p18_smash_s3_flipped.csv
# Created: p19_smash_s1_flipped.csv
# Created: p19_smash_s2_flipped.csv
# Created: p19_smash_s3_flipped.csv
# Created: p1_smash_s1_flipped.csv
# Created: p1_smash_s2_flipped.csv
# Created: p1_smash_s3_flipped.csv
# Created: p20_smash_s1_flipped.csv
# Created: p20_smash_s2_flipped.csv
# Created: p20_smash_s3_flipped.csv
# Created: p21_smash_s1_flipped.csv
# Created: p21_smash_s2_flipped.csv
# Created: p21_smash_s3_flipped.csv
# Created: p22_smash_s1_flipped.csv
# Created: p22_smash_s2_flipped.csv
# Created: p22_smash_s3_flipped.csv
# Created: p23_smash_s1_flipped.csv
# Created: p23_smash_s2_flipped.csv
# Created: p23_smash_s3_flipped.csv
# Created: p24_smash_s1_flipped.csv
# Created: p24_smash_s2_flipped.csv
# Created: p24_smash_s3_flipped.csv
# Created: p25_smash_s1_flipped.csv
# Created: p25_smash_s2_flipped.csv
# Created: p25_smash_s3_flipped.csv
# Created: p26_smash_s1_flipped.csv
# Created: p26_smash_s2_flipped.csv
# Created: p26_smash_s3_flipped.csv
# Created: p27_smash_s1_flipped.csv
# Created: p27_smash_s2_flipped.csv
# Created: p27_smash_s3_flipped.csv
# Created: p28_smash_s1_flipped.csv
# Created: p28_smash_s2_flipped.csv
# Created: p28_smash_s3_flipped.csv
# Created: p29_smash_s1_flipped.csv
# Created: p29_smash_s2_flipped.csv
# Created: p29_smash_s3_flipped.csv
# Created: p2_smash_s1_flipped.csv
# Created: p2_smash_s2_flipped.csv
# Created: p2_smash_s3_flipped.csv
# Created: p30_smash_s1_flipped.csv
# Created: p30_smash_s2_flipped.csv
# Created: p30_smash_s3_flipped.csv
# Created: p31_smash_s1_flipped.csv
# Created: p31_smash_s2_flipped.csv
# Created: p31_smash_s3_flipped.csv
# Created: p32_smash_s1_flipped.csv
# Created: p32_smash_s2_flipped.csv
# Created: p32_smash_s3_flipped.csv
# Created: p33_smash_s1_flipped.csv
# Created: p33_smash_s2_flipped.csv
# Created: p33_smash_s3_flipped.csv
# Created: p34_smash_s1_flipped.csv
# Created: p34_smash_s2_flipped.csv
# Created: p34_smash_s3_flipped.csv
# Created: p35_smash_s1_flipped.csv
# Created: p35_smash_s2_flipped.csv
# Created: p35_smash_s3_flipped.csv
# Created: p36_smash_s1_flipped.csv
# Created: p36_smash_s2_flipped.csv
# Created: p36_smash_s3_flipped.csv
# Created: p37_smash_s1_flipped.csv
# Created: p37_smash_s2_flipped.csv
# Created: p37_smash_s3_flipped.csv
# Created: p38_smash_s1_flipped.csv
# Created: p38_smash_s2_flipped.csv
# Created: p38_smash_s3_flipped.csv
# Created: p39_smash_s1_flipped.csv
# Created: p39_smash_s2_flipped.csv
# Created: p39_smash_s3_flipped.csv
# Created: p3_smash_s1_flipped.csv
# Created: p3_smash_s2_flipped.csv
# Created: p3_smash_s3_flipped.csv
# Created: p40_smash_s1_flipped.csv
# Created: p40_smash_s2_flipped.csv
# Created: p40_smash_s3_flipped.csv
# Created: p41_smash_s1_flipped.csv
# Created: p41_smash_s2_flipped.csv
# Created: p41_smash_s3_flipped.csv
# Created: p42_smash_s1_flipped.csv
# Created: p42_smash_s2_flipped.csv
# Created: p42_smash_s3_flipped.csv
# Created: p43_smash_s1_flipped.csv
# Created: p43_smash_s2_flipped.csv
# Created: p43_smash_s3_flipped.csv
# Created: p44_smash_s1_flipped.csv
# Created: p44_smash_s2_flipped.csv
# Created: p44_smash_s3_flipped.csv
# Created: p45_smash_s1_flipped.csv
# Created: p45_smash_s2_flipped.csv
# Created: p45_smash_s3_flipped.csv
# Created: p46_smash_s1_flipped.csv
# Created: p46_smash_s2_flipped.csv
# Created: p46_smash_s3_flipped.csv
# Created: p47_smash_s1_flipped.csv
# Created: p47_smash_s2_flipped.csv
# Created: p47_smash_s3_flipped.csv
# Created: p48_smash_s1_flipped.csv
# Created: p48_smash_s2_flipped.csv
# Created: p48_smash_s3_flipped.csv
# Created: p49_smash_s1_flipped.csv
# Created: p49_smash_s2_flipped.csv
# Created: p49_smash_s3_flipped.csv
# Created: p4_smash_s1_flipped.csv
# Created: p4_smash_s2_flipped.csv
# Created: p4_smash_s3_flipped.csv
# Created: p50_smash_s1_flipped.csv
# Created: p50_smash_s2_flipped.csv
# Created: p50_smash_s3_flipped.csv
# Created: p51_smash_s1_flipped.csv
# Created: p51_smash_s2_flipped.csv
# Created: p51_smash_s3_flipped.csv
# Created: p52_smash_s1_flipped.csv
# Created: p52_smash_s2_flipped.csv
# Created: p52_smash_s3_flipped.csv
# Created: p53_smash_s1_flipped.csv
# Created: p53_smash_s2_flipped.csv
# Created: p53_smash_s3_flipped.csv
# Created: p54_smash_s1_flipped.csv
# Created: p54_smash_s2_flipped.csv
# Created: p54_smash_s3_flipped.csv
# Created: p55_smash_s1_flipped.csv
# Created: p55_smash_s2_flipped.csv
# Created: p55_smash_s3_flipped.csv
# Created: p5_smash_s1_flipped.csv
# Created: p5_smash_s2_flipped.csv
# Created: p5_smash_s3_flipped.csv
# Created: p6_smash_s1_flipped.csv
# Created: p6_smash_s2_flipped.csv
# Created: p6_smash_s3_flipped.csv
# Created: p7_smash_s1_flipped.csv
# Created: p7_smash_s2_flipped.csv
# Created: p7_smash_s3_flipped.csv
# Created: p8_smash_s1_flipped.csv
# Created: p8_smash_s2_flipped.csv
# Created: p8_smash_s3_flipped.csv
# Created: p9_smash_s1_flipped.csv
# Created: p9_smash_s2_flipped.csv
# Created: p9_smash_s3_flipped.csv
# Succeeded. Mirror augmentation complete.

# %% [markdown]
# ### Train/Test/validation split

# %% [markdown]
# #### to counter memory leakage, we need to make sure that the same video plus his fliped video in the same split

# %%
OOT_DIR = r'C:\Users\Noam\OneDrive\Desktop\DL_project\dataset\PROCESSED_DATA'

def get_base_name(filename):
    # to prevent memory leakage
    name_without_ext = os.path.splitext(filename)[0]
    if name_without_ext.endswith('_flipped'):
        return name_without_ext.replace('_flipped', '')
    return name_without_ext


grouped_files = defaultdict(list)
file_labels = {} 

for root, dirs, files in os.walk(ROOT_DIR):
    for file in files:
        if file.endswith(".csv"):
            full_path = os.path.join(root, file)
            
            # folder name is the label
            label = os.path.basename(root)
            
            base_name = get_base_name(file)
            unique_id = f"{label}_{base_name}" # to prevent same name
            
            grouped_files[unique_id].append(full_path)
            file_labels[unique_id] = label

# split
all_unique_ids = list(grouped_files.keys())
all_labels = [file_labels[uid] for uid in all_unique_ids]

print(f"Total unique sequences found: {len(all_unique_ids)}")

# train/test/validation
train_ids, temp_ids, train_labels, temp_labels = train_test_split(
    all_unique_ids, all_labels, 
    test_size=0.2, 
    random_state=42, 
    stratify=all_labels # all of the classes in all of the splits
)

val_ids, test_ids, _, _ = train_test_split(
    temp_ids, temp_labels, 
    test_size=0.5, 
    random_state=42, 
    stratify=temp_labels
)

# return list
def flatten_file_list(id_list):
    final_files = []
    labels = []
    for uid in id_list:
        files = grouped_files[uid]
        final_files.extend(files)
        labels.extend([file_labels[uid]] * len(files))
    return final_files, labels

train_files, train_y = flatten_file_list(train_ids)
val_files, val_y = flatten_file_list(val_ids)
test_files, test_y = flatten_file_list(test_ids)

print(f"Train files: {len(train_files)}")
print(f"Val files:   {len(val_files)}")
print(f"Test files:  {len(test_files)}")

# example
print("Example Train File:", train_files[0])
print("Example Label:", train_y[0])
# Out:
# Total unique sequences found: 1980
# Train files: 3168
# Val files:   396
# Test files:  396
# Example Train File: C:\Users\Noam\OneDrive\Desktop\DL_project\dataset\PROCESSED_DATA\forehand_openstands\p22_foreopen_s2.csv
# Example Label: forehand_openstands
